# %% [markdown]
#  **Workspace Setup**
#
#  For this summarization model, you must adjust your runtime space from CPU to GPU. We do this for the express purpose of reducing total runtime for the summarization model [Adjust this explaination]
#
# To switch from CPU to GPU, select:
# Runtime > Change runtime type > T4 GPU

# %% [markdown]
# **Necessary User Imports and Downloads**

# %%
# !pip install PyMuPDF -q
# !pip install -U datasets transformers ninja -q
# !pip install -U sentencepiece -q
# !pip install clean-text[gpl] -q
# !pip install ads -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.9 MB/s eta 0:00:00
#   Building wheel for emoji (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for ads (setup.py) ... done
#   Building wheel for httpretty (setup.py) ... done

# %%
import pandas as pd
import time
import multiprocessing
import re
import requests
import os
import concurrent.futures
import fitz

#For summarization
from transformers import pipeline
import torch
from cleantext import clean
from pathlib import Path
import logging
from datasets import load_dataset
from tqdm.auto import tqdm
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM

#From Expertise Finder v2.0
import TextAnalysis as TA

#For N-grams
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# **Citing this code**
#
# This code is an enhancement or addition to the Expertise finding tool developed by Volz et al. 2023. When citing this particular summarization code, please use Hoare et al. 2024.

# %% [markdown]
# Import .csv file produced from Expertise Finder v2.0 code (*Helfenbein et al. 2023)*. This code will only work with results produced by ADS_search.

# %%
datf = pd.read_csv('HowardExample.csv')
datf.set_index(datf.columns[0], inplace=True, drop=True)

datf
# Out:
#                                                                   Input Institution  \
# Input Author
# Abdullah, Ajamu                                                   Howard University
# Allen, Walter W., Jr.                                             Howard University
# Anusie, Steve                                                     Howard University
# Bacha, Tulu                                                       Howard University
# Blake, Ameer                                                      Howard University
# Brown, Beth A.                                 Howard University, Howard University
# Coley, J. B.                                                      Howard University
# Coley, Joel                                    Howard University, Howard University
# Coley, Joel B.                    Howard University, Howard University, Howard U...
# David-Uraz, A.                                 Howard University, Howard University
# Dumervil, S.                                                      Howard University
# Fahr, A.                                                          Howard University
# Finch, Tehani K.                               Howard University, Howard University
# Fletcher, Alex                                                    Howard University
# Garcia-Sanchez, Raul F.                                           Howard University
# Halpern, J. B.                                                    Howard University
# Howard, S. K.                                                     Howard University
# Howard, Stephanie                                                 Howard University
# Howard, Stephanie K.                                              Howard University
# Hubbard, Ryan J.                                                  Howard University
# Huber, Tito E.                                                    Howard University
# Hughes, Andréa. C. G.                                             Howard University
# Hübsch, Tristan                                Howard University, Howard University
# Jenkins, G. S.                                                    Howard University
# Jenkins, Gregory S.               Howard University, Howard University, Howard U...
# Lewis, J. M. T.                                                   Howard University
# Lindesay, James                   Howard University, Howard University, Howard U...
# Mann, Ayanna                                                      Howard University
# Manning, Sinclaire                             Howard University, Howard University
# Mbaye, Mamadou Thiao                                              Howard University
# McGee, Carissma                                                   Howard University
# Mensah, Francis Emmanuel Tofodji                                  Howard University
# Misra, P.                                                         Howard University
# Moore, H.                                                         Howard University
# Morse, Z.                                                         Howard University
# Morse, Zachary R.                                                 Howard University
# N'Doumi, M.                                                       Howard University
# Ohi, Seigo                                                        Howard University
# Olsen, K.                                                         Howard University
# Pope, Myles                                                       Howard University
# Qasim, Danna                                                      Howard University
# Reynolds, M. A.                                Howard University, Howard University
# Roi Smith, Sergio                                                 Howard University
# Sakai, R. K.                                                      Howard University
# Schwartzman, D. W.                             Howard University, Howard University
# Schwartzman, David                Howard University, Howard University, Howard U...
# Strong, Avaine                                                    Howard University
# Thomas, Brianna P.                Howard University, Howard University, Howard U...
# Thorpe, A. N.                                                     Howard University
# Vidaurri, Monica R.                                               Howard University
# Walker, Ashley                    Howard University, Howard University, Howard U...
# Weber, Tristan                                                    Howard University
# Whiteman, D. N.                                                   Howard University
# Wofford, A.                                    Howard University, Howard University
# Yarber, Aara'L.                                Howard University, Howard University
#
#                                                                        First Author  \
# Input Author
# Abdullah, Ajamu                                                     Abdullah, Ajamu
# Allen, Walter W., Jr.                                         Allen, Walter W., Jr.
# Anusie, Steve                                                         Anusie, Steve
# Bacha, Tulu                                                             Bacha, Tulu
# Blake, Ameer                                                           Blake, Ameer
# Brown, Beth A.                                       Brown, Beth A., Brown, Beth A.
# Coley, J. B.                                                           Coley, J. B.
# Coley, Joel                                                Coley, Joel, Coley, Joel
# Coley, Joel B.                       Coley, Joel B., Coley, Joel B., Coley, Joel B.
# David-Uraz, A.                                       David-Uraz, A., David-Uraz, A.
# Dumervil, S.                                                           Dumervil, S.
# Fahr, A.                                                                   Fahr, A.
# Finch, Tehani K.                                 Finch, Tehani K., Finch, Tehani K.
# Fletcher, Alex                                                       Fletcher, Alex
# Garcia-Sanchez, Raul F.                                     Garcia-Sanchez, Raul F.
# Halpern, J. B.                                                       Halpern, J. B.
# Howard, S. K.                                                         Howard, S. K.
# Howard, Stephanie                                                 Howard, Stephanie
# Howard, Stephanie K.                                           Howard, Stephanie K.
# Hubbard, Ryan J.                                                   Hubbard, Ryan J.
# Huber, Tito E.                                                       Huber, Tito E.
# Hughes, Andréa. C. G.                                         Hughes, Andréa. C. G.
# Hübsch, Tristan                                    Hübsch, Tristan, Hübsch, Tristan
# Jenkins, G. S.                                                       Jenkins, G. S.
# Jenkins, Gregory S.               Jenkins, Gregory S., Jenkins, Gregory S., Jenk...
# Lewis, J. M. T.                                                     Lewis, J. M. T.
# Lindesay, James                   Lindesay, James, Lindesay, James, Lindesay, Ja...
# Mann, Ayanna                                                           Mann, Ayanna
# Manning, Sinclaire                           Manning, Sinclaire, Manning, Sinclaire
# Mbaye, Mamadou Thiao                                           Mbaye, Mamadou Thiao
# McGee, Carissma                                                     McGee, Carissma
# Mensah, Francis Emmanuel Tofodji                   Mensah, Francis Emmanuel Tofodji
# Misra, P.                                                                 Misra, P.
# Moore, H.                                                                 Moore, H.
# Morse, Z.                                                                 Morse, Z.
# Morse, Zachary R.                                                 Morse, Zachary R.
# N'Doumi, M.                                                             N'Doumi, M.
# Ohi, Seigo                                                               Ohi, Seigo
# Olsen, K.                                                                 Olsen, K.
# Pope, Myles                                                             Pope, Myles
# Qasim, Danna                                                           Qasim, Danna
# Reynolds, M. A.                                    Reynolds, M. A., Reynolds, M. A.
# Roi Smith, Sergio                                                 Roi Smith, Sergio
# Sakai, R. K.                                                           Sakai, R. K.
# Schwartzman, D. W.                           Schwartzman, D. W., Schwartzman, D. W.
# Schwartzman, David                Schwartzman, David, Schwartzman, David, Schwar...
# Strong, Avaine                                                       Strong, Avaine
# Thomas, Brianna P.                Thomas, Brianna P., Thomas, Brianna P., Thomas...
# Thorpe, A. N.                                                         Thorpe, A. N.
# Vidaurri, Monica R.                                             Vidaurri, Monica R.
# Walker, Ashley                    Walker, Ashley, Walker, Ashley, Walker, Ashley...
# Weber, Tristan                                                       Weber, Tristan
# Whiteman, D. N.                                                     Whiteman, D. N.
# Wofford, A.                                                Wofford, A., Wofford, A.
# Yarber, Aara'L.                                    Yarber, Aara'L., Yarber, Aara'L.
#
#                                                                             Bibcode  \
# Input Author
# Abdullah, Ajamu                                                 2014AAS...22324403A
# Allen, Walter W., Jr.                                           2009PhDT.........1A
# Anusie, Steve                                                   2019AAS...23325917A
# Bacha, Tulu                                                     2011PhDT.........7B
# Blake, Ameer                                                    2016AAS...22713710B
# Brown, Beth A.                            2010AIPC.1280....3B,\n2008CQGra..25j5026B
# Coley, J. B.                                                    2020AAS...23545701C
# Coley, Joel                               2023AAS...24142807C,\n2022HEAD...1940601C
# Coley, Joel B.                    2019ApJ...879...34C,\n2019AAS...23323601C,\n20...
# David-Uraz, A.                            2021MNRAS.504.4841D,\n2021MNRAS.501.2677D
# Dumervil, S.                                                    2020AGUFMP076.0002D
# Fahr, A.                                                        2011epsc.conf...11F
# Finch, Tehani K.                          2009JHEP...03..145F,\n2002ApJ...577...51F
# Fletcher, Alex                                                  2004SPIE.5371..195F
# Garcia-Sanchez, Raul F.                                         2014isms.confEMJ07G
# Halpern, J. B.                                                  2011AGUFM.P13A1645H
# Howard, S. K.                                                   2020AGUFMU008...06H
# Howard, Stephanie                                               2021AGUFMSM51C..06H
# Howard, Stephanie K.                                            2022AGUFMSM25A..05H
# Hubbard, Ryan J.                                                2016AAS...22733403H
# Huber, Tito E.                                                  2001AIPC..552.1113H
# Hughes, Andréa. C. G.                                           2023JGRA..12831838H
# Hübsch, Tristan                           2012IJMPA..2750173H,\n2005ppu..conf..261H
# Jenkins, G. S.                                                  2004AGUSM.U22A..05J
# Jenkins, Gregory S.               2012GeoRL..3920810J,\n2008GeoRL..3512806J,\n20...
# Lewis, J. M. T.                                                 2021JGRE..12606803L
# Lindesay, James                   2012FoPh...42.1573L,\n2010CQGra..27u5015L,\n20...
# Mann, Ayanna                                                    2023AAS...24120511M
# Manning, Sinclaire                        2015AAS...22514338M,\n2013AAS...22144203M
# Mbaye, Mamadou Thiao                                            2014PhDT.......274M
# McGee, Carissma                                                 2023AAS...24117763M
# Mensah, Francis Emmanuel Tofodji                                2007PhDT........23M
# Misra, P.                                                       2012AGUFM.P13A1893M
# Moore, H.                                                       2002AGUSM.A22B..11M
# Morse, Z.                                                       2020AGUFMP063...02M
# Morse, Zachary R.                                               2021PSJ.....2..167M
# N'Doumi, M.                                                     2011AGUFM.P33A1750N
# Ohi, Seigo                                                      2004AIPC..699..938O
# Olsen, K.                                                       2020AGUFMP086...02O
# Pope, Myles                                                     2023AAS...24140126P
# Qasim, Danna                                                    2022ApJ...929..176Q
# Reynolds, M. A.                           2001JASTP..63.1267R,\n2001AGUSM..SM52D07R
# Roi Smith, Sergio                                               2017AAS...22924203R
# Sakai, R. K.                                                    2011AGUFM.A41A0032S
# Schwartzman, D. W.                        2014AGUFM.P11C3775S,\n2006GeCAS..70Q.567S
# Schwartzman, David                2011OLEB...41..581S,\n2008AsBio...8..187S,\n20...
# Strong, Avaine                                                  2000PhDT.......340S
# Thomas, Brianna P.                2017AAS...22943501T,\n2016AAS...22713819T,\n20...
# Thorpe, A. N.                                                   2002M&PS...37..763T
# Vidaurri, Monica R.                                             2022PSJ.....3..137V
# Walker, Ashley                    2023AAS...24110401W,\n2023AAS...24116201W,\n20...
# Weber, Tristan                                                  2022GeoRL..4998633W
# Whiteman, D. N.                                                 2020AGUFMED005..05W
# Wofford, A.                               2021AAS...23753511W,\n2020AAS...23537712W
# Yarber, Aara'L.                           2015AAS...22525022Y,\n2014AAS...22325219Y
#
#                                                                               Title  \
# Input Author
# Abdullah, Ajamu                                      New Star Formation in NGC 3690
# Allen, Walter W., Jr.             The canonical proper-time theory applied to pa...
# Anusie, Steve                     The Mini-MUSCLES Treasury Survey: Measurements...
# Bacha, Tulu                       Effects of Cloud on Goddard Lidar Observatory ...
# Blake, Ameer                      A CubeSat to Search for Transiting Planets Aro...
# Brown, Beth A.                    Causal Structures of Dynamic Black Holes, Cons...
# Coley, J. B.                      A Study of the Extragalactic Gamma-ray Binary ...
# Coley, Joel                       A Study of the 2020 Type II Giant Outburst of ...
# Coley, Joel B.                    A Study of the 20 day Superorbital Modulation ...
# David-Uraz, A.                    MOBSTER - IV. Detection of a new magnetic B-ty...
# Dumervil, S.                      Electrical Conductivity and Magnetic Induction...
# Fahr, A.                          Pressure Effects on Product Channels of Hydroc...
# Finch, Tehani K.                  Three-charge supertubes in a rotating black ho...
# Fletcher, Alex                    Toward public volume database management: a ca...
# Garcia-Sanchez, Raul F.           Distinctions in the Raman Spectroscopy Feature...
# Halpern, J. B.                    Pressure Effects on Product Channels of the Al...
# Howard, S. K.                     Characteristics of Ultra Low Frequency Plasma ...
# Howard, Stephanie                 Voyager 2 Magnetic Field Data Near Closest App...
# Howard, Stephanie K.              Current State of a Magnetospheric Disturbance ...
# Hubbard, Ryan J.                  Identifying Extraplanar Diffuse Ionized Gas in...
# Huber, Tito E.                    Thermomagnetic coolers based on Bi and Bi-Sb n...
# Hughes, Andréa. C. G.             Advancing Our Understanding of Martian Proton ...
# Hübsch, Tristan                   On the Construction and the Structure of Off-S...
# Jenkins, G. S.                    High obliquity simulations of Proterozoic clim...
# Jenkins, Gregory S.               The influence of the SAL and lightning on trop...
# Lewis, J. M. T.                   Pyrolysis of Oxalate, Acetate, and Perchlorate...
# Lindesay, James                   Self-consistent Solutions of Canonical Proper ...
# Mann, Ayanna                      Improved Model Of Optical Elements Involved In...
# Manning, Sinclaire                Probing the Magnetic Fields in the Environment...
# Mbaye, Mamadou Thiao                        Adsorption of Gases on Carbon Nanotubes
# McGee, Carissma                   Dark Matter Accounts for Perturbation in the G...
# Mensah, Francis Emmanuel Tofodji  Use of the selected overlap LIDAR experiment (...
# Misra, P.                         Organic Contaminants Library for the Sample An...
# Moore, H.                         Analysis of the Temporal Characteristics of th...
# Morse, Z.                         Developing AN Augmented Reality Application fo...
# Morse, Zachary R.                 Detailed Morphologic Mapping and Traverse Plan...
# N'Doumi, M.                       Radiative Lifetimes of\nNH<SUB>2</SUB>(\Atilde...
# Ohi, Seigo                        The Hematopoietic Stem Cell Therapy for Explor...
# Olsen, K.                         Deformation along Enceladus' Tiger Stripes: In...
# Pope, Myles                             Accurate Masses of Extraordinary Red Giants
# Qasim, Danna                      Radiation-induced D/H Exchange Rate Constants ...
# Reynolds, M. A.                   Equatorial coupling between the plasmasphere a...
# Roi Smith, Sergio                      Long-Term Timing of Globular Cluster Pulsars
# Sakai, R. K.                      Ozone Development and Destruction in the Plane...
# Schwartzman, D. W.                Habitability for Complex Life and the Developm...
# Schwartzman, David                Multiple Paths to Encephalization and Technica...
# Strong, Avaine                    On the deployment and station keeping dynamics...
# Thomas, Brianna P.                Revisiting the Trend of Debris Disks with rega...
# Thorpe, A. N.                     Magnetic study of magnetite in the Tagish Lake...
# Vidaurri, Monica R.               The Outer Edge of the Venus Zone around Main-s...
# Walker, Ashley                    Modeling Cloud Microphysics in Ice Giant Atmos...
# Weber, Tristan                    Updated Spherical Harmonic Magnetic Field Mome...
# Whiteman, D. N.                   Planetary Boundary Layer Workshop in the Time ...
# Wofford, A.                       Towards the development of a STEAM rural broad...
# Yarber, Aara'L.                   Mapping the Star Formation in NGC 1097 Using t...
#
#                                                                    Publication Date  \
# Input Author
# Abdullah, Ajamu                                                          2014-01-00
# Allen, Walter W., Jr.                                                    2009-00-00
# Anusie, Steve                                                            2019-01-00
# Bacha, Tulu                                                              2011-00-00
# Blake, Ameer                                                             2016-01-00
# Brown, Beth A.                                               2010-10-00, 2008-05-00
# Coley, J. B.                                                             2020-01-00
# Coley, Joel                                                  2023-01-00, 2022-04-00
# Coley, Joel B.                                   2019-07-00, 2019-01-00, 2019-01-00
# David-Uraz, A.                                               2021-07-00, 2021-02-00
# Dumervil, S.                                                             2020-12-00
# Fahr, A.                                                                 2011-10-00
# Finch, Tehani K.                                             2009-03-00, 2002-09-00
# Fletcher, Alex                                                           2004-04-00
# Garcia-Sanchez, Raul F.                                                  2014-06-00
# Halpern, J. B.                                                           2011-12-00
# Howard, S. K.                                                            2020-12-00
# Howard, Stephanie                                                        2021-12-00
# Howard, Stephanie K.                                                     2022-12-00
# Hubbard, Ryan J.                                                         2016-01-00
# Huber, Tito E.                                                           2001-02-00
# Hughes, Andréa. C. G.                                                    2023-10-00
# Hübsch, Tristan                                              2012-11-00, 2005-00-00
# Jenkins, G. S.                                                           2004-05-00
# Jenkins, Gregory S.               2012-10-00, 2008-06-00, 2008-06-00, 2008-04-00...
# Lewis, J. M. T.                                                          2021-04-00
# Lindesay, James                   2012-12-00, 2010-11-00, 2010-10-00, 2009-06-00...
# Mann, Ayanna                                                             2023-01-00
# Manning, Sinclaire                                           2015-01-00, 2013-01-00
# Mbaye, Mamadou Thiao                                                     2014-01-00
# McGee, Carissma                                                          2023-01-00
# Mensah, Francis Emmanuel Tofodji                                         2007-00-00
# Misra, P.                                                                2012-12-00
# Moore, H.                                                                2002-05-00
# Morse, Z.                                                                2020-12-00
# Morse, Zachary R.                                                        2021-08-00
# N'Doumi, M.                                                              2011-12-00
# Ohi, Seigo                                                               2004-02-00
# Olsen, K.                                                                2020-12-00
# Pope, Myles                                                              2023-01-00
# Qasim, Danna                                                             2022-04-00
# Reynolds, M. A.                                              2001-07-00, 2001-05-00
# Roi Smith, Sergio                                                        2017-01-00
# Sakai, R. K.                                                             2011-12-00
# Schwartzman, D. W.                                           2014-12-00, 2006-08-00
# Schwartzman, David                               2011-12-00, 2008-02-00, 2000-00-00
# Strong, Avaine                                                           2000-00-00
# Thomas, Brianna P.                               2017-01-00, 2016-01-00, 2015-01-00
# Thorpe, A. N.                                                            2002-05-00
# Vidaurri, Monica R.                                                      2022-06-00
# Walker, Ashley                       2023-01-00, 2023-01-00, 2022-12-00, 2022-12-00
# Weber, Tristan                                                           2022-12-00
# Whiteman, D. N.                                                          2020-12-00
# Wofford, A.                                                  2021-01-00, 2020-01-00
# Yarber, Aara'L.                                              2015-01-00, 2014-01-00
#
#                                                                            Keywords  \
# Input Author
# Abdullah, Ajamu                                                                 NaN
# Allen, Walter W., Jr.             Canonical proper-time, Euler-Lagrange equation...
# Anusie, Steve                                                                   NaN
# Bacha, Tulu                       Earth sciences, Clouds, Errors, Wind speed, Op...
# Blake, Ameer                                                                    NaN
# Brown, Beth A.                    black holes, space-time configurations, satell...
# Coley, J. B.                                                                    NaN
# Coley, Joel                                                                      ,
# Coley, Joel B.                    accretion, accretion disks, stars: individual:...
# David-Uraz, A.                    techniques: photometric, techniques: polarimet...
# Dumervil, S.                      0738 Ice, CRYOSPHERE, 4299 General or miscella...
# Fahr, A.                                                                        NaN
# Finch, Tehani K.                  High Energy Physics - Theory, General Relativi...
# Fletcher, Alex                                                                  NaN
# Garcia-Sanchez, Raul F.                              Analytical, Combustion, Plasma
# Halpern, J. B.                    5405 PLANETARY SCIENCES: SOLID SURFACE PLANETS...
# Howard, S. K.                     0810 Post-secondary education, EDUCATION, 0815...
# Howard, Stephanie                                                               NaN
# Howard, Stephanie K.                                                            NaN
# Hubbard, Ryan J.                                                                NaN
# Huber, Tito E.                    84.60.-h, 07.87.+v, Direct energy conversion a...
# Hughes, Andréa. C. G.             Mars, aurora, proton aurora, proton/hydrogen p...
# Hübsch, Tristan                   Supersymmetry, off-shell supermultiplets, worl...
# Jenkins, G. S.                    0343 Planetary atmospheres (5405, 5407, 5409, ...
# Jenkins, Gregory S.               Atmospheric Composition and Structure: Aerosol...
# Lewis, J. M. T.                   acetate, Mars, organic salt, oxalate, perchlor...
# Lindesay, James                   Quantum gravitation, Canonical gravitation, Ge...
# Mann, Ayanna                                                                    NaN
# Manning, Sinclaire                                                               ,
# Mbaye, Mamadou Thiao              Physics, Condensed Matter;Physics, Astronomy a...
# McGee, Carissma                                                                 NaN
# Mensah, Francis Emmanuel Tofodji  Selected overlap LIDAR, SOLEX, LIDAR, Water va...
# Misra, P.                         1976 INFORMATICS / Software tools and services...
# Moore, H.                                                       3360 Remote sensing
# Morse, Z.                         6207 Comparative planetology, PLANETARY SCIENC...
# Morse, Zachary R.                 Lunar impacts, Lunar surface, Rovers, Lunar cr...
# N'Doumi, M.                       6000 PLANETARY SCIENCES: COMETS AND SMALL BODI...
# Ohi, Seigo                        87.65.+y, 87.16.-b, 07.87.+v, Aerospace bio- a...
# Olsen, K.                         0738 Ice, CRYOSPHERE, 4299 General or miscella...
# Pope, Myles                                                                     NaN
# Qasim, Danna                      Ice destruction, Cosmic rays, Laboratory astro...
# Reynolds, M. A.                   , 2443 Midlatitude ionosphere, 2481 Topside io...
# Roi Smith, Sergio                                                               NaN
# Sakai, R. K.                      0345 ATMOSPHERIC COMPOSITION AND STRUCTURE / P...
# Schwartzman, D. W.                1605 Abrupt/rapid climate change, GLOBAL CHANG...
# Schwartzman, David                Biosphere, Encephalization, Temperature, Oxyge...
# Strong, Avaine                                                                  NaN
# Thomas, Brianna P.                                                             , ,
# Thorpe, A. N.                                                                   NaN
# Vidaurri, Monica R.               Venus, Carbon dioxide, Greenhouse gases, Habit...
# Walker, Ashley                                                               , , ,
# Weber, Tristan                    Ganymede, magnetic field, spherical harmonics,...
# Whiteman, D. N.                   0820 Curriculum and laboratory design, EDUCATI...
# Wofford, A.                                                                      ,
# Yarber, Aara'L.                                                                  ,
#
#                                                                        Affiliations  \
# Input Author
# Abdullah, Ajamu                                                   Howard University
# Allen, Walter W., Jr.                                             Howard University
# Anusie, Steve                     Howard University, Washington,\nDC, United States
# Bacha, Tulu                                                       Howard University
# Blake, Ameer                                                      Howard University
# Brown, Beth A.                    NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Coley, J. B.                      Department of Physics, Howard\nUniversity, Was...
# Coley, Joel                                   Howard University, Howard\nUniversity
# Coley, Joel B.                    Department of Physics and\nAstronomy, Howard U...
# David-Uraz, A.                    Department of Physics and\nAstronomy, and Bart...
# Dumervil, S.                      Chemical Engineering, Howard\nUniversity, Wash...
# Fahr, A.                          Howard University, Department\nof Chemistry, W...
# Finch, Tehani K.                  Department of Physics and\nAstronomy, Howard U...
# Fletcher, Alex                                                    Howard Univ., USA
# Garcia-Sanchez, Raul F.           Howard University, Department\nof Physics and ...
# Halpern, J. B.                        Chemistry, Howard Univ,\nWashington, DC, USA;
# Howard, S. K.                     Howard University, Washington,\nDC, United States
# Howard, Stephanie                     Howard University, Washington,\nUnited States
# Howard, Stephanie K.                  Howard University, Washington,\nUnited States
# Hubbard, Ryan J.                                                  Howard University
# Huber, Tito E.                    Department of Chemistry,\nHoward University, W...
# Hughes, Andréa. C. G.             NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Hübsch, Tristan                   Department of Physics and\nAstronomy, Howard U...
# Jenkins, G. S.                    Howard University, Department\nof Physics and ...
# Jenkins, Gregory S.               Department of Physics and\nAstronomy, Howard U...
# Lewis, J. M. T.                   Department of Physics and\nAstronomy, Howard U...
# Lindesay, James                   Computational Physics\nLaboratory, Howard Univ...
# Mann, Ayanna                                                      Howard University
# Manning, Sinclaire                            Howard University, Howard\nUniversity
# Mbaye, Mamadou Thiao                                              Howard University
# McGee, Carissma                                                   Howard University
# Mensah, Francis Emmanuel Tofodji                                  Howard University
# Misra, P.                         Department of Physics &amp;\nAstronomy, Howard...
# Moore, H.                         Howard University, 2355 Sixth\nSt. NW, Washing...
# Morse, Z.                         Howard University, Washington,\nDC, United States
# Morse, Zachary R.                 Department of Physics and\nAstronomy, Howard U...
# N'Doumi, M.                       Chemistry, Howard University,\nWashington, DC,...
# Ohi, Seigo                        Howard University and\nHospital, Washington, DC .
# Olsen, K.                         Physics and Astronomy, Howard\nUniversity, Was...
# Pope, Myles                                                       Howard University
# Qasim, Danna                      Astrochemistry Laboratory,\nNASA Goddard Space...
# Reynolds, M. A.                   Department of Physics and\nAstronomy, Howard U...
# Roi Smith, Sergio                                                 Howard University
# Sakai, R. K.                               Howard University, Beltsville,\nMD, USA;
# Schwartzman, D. W.                Biology, Howard University,\nWashington, DC, U...
# Schwartzman, David                Department of Biology, Howard\nUniversity, Was...
# Strong, Avaine                                    Howard University, United\nStates
# Thomas, Brianna P.                Howard University, Howard\nUniversity, Howard ...
# Thorpe, A. N.                     Department of Physics, Howard\nUniversity, Was...
# Vidaurri, Monica R.               Department of Physics and\nAstronomy, Howard U...
# Walker, Ashley                    Howard University, Howard\nUniversity, Howard ...
# Weber, Tristan                    NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Whiteman, D. N.                   Howard University, Washington,\nDC, United States
# Wofford, A.                       Howard University, Washington\nD.c., DC, Howar...
# Yarber, Aara'L.                               Howard University, Howard\nUniversity
#
#                                                                            Abstract  \
# Input Author
# Abdullah, Ajamu                   NGC 3690 is a system of merging spiral galaxie...
# Allen, Walter W., Jr.             This research dissertation has three objective...
# Anusie, Steve                     Astronomers are becoming more interested in fi...
# Bacha, Tulu                       The Goddard Lidar Observatory for Wind (GLOW),...
# Blake, Ameer                      The goal of this project is to further our gro...
# Brown, Beth A.                    Dynamic space-times, especially those manifest...
# Coley, J. B.                      We report on XMM-Newton, Nuclear Spectroscopic...
# Coley, Joel                       We report on Neutron Star Interior Composition...
# Coley, Joel B.                    We report on Nuclear Spectroscopic Telescope A...
# David-Uraz, A.                    In this paper, we present results from the spe...
# Dumervil, S.                      Europa, a Galilean moon, and other icy ocean w...
# Fahr, A.                          Previously we had studied the kinetics and pro...
# Finch, Tehani K.                  The low velocity scattering of a D0-F1 supertu...
# Fletcher, Alex                    Public databases today can be constructed with...
# Garcia-Sanchez, Raul F.           Metal oxides are widely used in gas sensor app...
# Halpern, J. B.                    Relatively large hydrocarbon molecules (C4, C6...
# Howard, S. K.                     Lacking a global magnetic field and atmosphere...
# Howard, Stephanie                 In August 1989, Voyager 2 became the first and...
# Howard, Stephanie K.              During its time at Mars, MAVEN has observed mu...
# Hubbard, Ryan J.                  The efficiency with which galaxies convert gas...
# Huber, Tito E.                    Bulk Bi, a semimetal, and Bi-Sb, have the high...
# Hughes, Andréa. C. G.             Proton aurora are the most commonly observed y...
# Hübsch, Tristan                   Recent efforts to classify representations of ...
# Jenkins, G. S.                    Results from GCM simulations using boundary co...
# Jenkins, Gregory S.               We present results for multiple Saharan Air La...
# Lewis, J. M. T.                   Organic salts, such as Fe, Ca, and Mg oxalates...
# Lindesay, James                   Generic self-gravitating quantum solutions tha...
# Mann, Ayanna                      Large optical surveys have always been a very ...
# Manning, Sinclaire                We present a rotation measure survey of radio ...
# Mbaye, Mamadou Thiao              This research focus in studying the interactio...
# McGee, Carissma                   The longest recognized stellar stream in the M...
# Mensah, Francis Emmanuel Tofodji  Water vapor is one of the most important atmos...
# Misra, P.                         A library containing mass spectra for Sample A...
# Moore, H.                         We have developed a KrF Lidar system (248 nm) ...
# Morse, Z.                                                                       NaN
# Morse, Zachary R.                 Schrödinger basin, a 312 km diameter complex i...
# N'Doumi, M.                       Fluorescence (X<SUP>2</SUP>B<SUB>1</SUB> ← \At...
# Ohi, Seigo                        Astronauts experience severe/invasive disorder...
# Olsen, K.                         Enceladus' Tiger Stripe fractures and their je...
# Pope, Myles                       Mass and radius measurements for red giant sta...
# Qasim, Danna                      Gas-phase and solid-state chemistry in low-tem...
# Reynolds, M. A.                   A multispecies kinetic model of the thermal pl...
# Roi Smith, Sergio                 Pulsar timing is a powerful astrophysical tool...
# Sakai, R. K.                      During the DISCOVER-AQ experiment several plat...
# Schwartzman, D. W.                We submit that the tightly coupled coevolution...
# Schwartzman, David                We propose consideration of at least two possi...
# Strong, Avaine                    This research explores the theory of relative ...
# Thomas, Brianna P.                Finding excess infrared emission around a star...
# Thorpe, A. N.                     The saturation magnetization, saturation reman...
# Vidaurri, Monica R.               A key item of interest for planetary scientist...
# Walker, Ashley                    The atmospheric composition of the ice giants,...
# Weber, Tristan                    In this study, we use data from the Juno and G...
# Whiteman, D. N.                   We were funded to host a 2-week workshop in th...
# Wofford, A.                       Inspired by high-impact scientific results fro...
# Yarber, Aara'L.                   We present new C- and L-band VLA continuum obs...
#
#                                                                          Identifier  \
# Input Author
# Abdullah, Ajamu                                                 2014AAS...22324403A
# Allen, Walter W., Jr.                                           2009PhDT.........1A
# Anusie, Steve                                                   2019AAS...23325917A
# Bacha, Tulu                                                     2011PhDT.........7B
# Blake, Ameer                                                    2016AAS...22713710B
# Brown, Beth A.                    10.1063/1.3507200, arXiv:0904.4192, 2010AIPC.1...
# Coley, J. B.                                                    2020AAS...23545701C
# Coley, Joel                                2023AAS...24142807C, 2022HEAD...1940601C
# Coley, Joel B.                    2019ApJ...879...34C, arXiv:1905.08817, 2019arX...
# David-Uraz, A.                    2021MNRAS.tmp..907D, 2021MNRAS.504.4841D, 10.1...
# Dumervil, S.                                                    2020AGUFMP076.0002D
# Fahr, A.                                   2011DPS....43...11F, 2011epsc.conf...11F
# Finch, Tehani K.                  arXiv:hep-th/0612085, 10.48550/arXiv.hep-th/06...
# Fletcher, Alex                               2004SPIE.5371..195F, 10.1117/12.535376
# Garcia-Sanchez, Raul F.                10.15278/isms.2014.MJ07, 2014isms.confEMJ07G
# Halpern, J. B.                                                  2011AGUFM.P13A1645H
# Howard, S. K.                                                   2020AGUFMU008...06H
# Howard, Stephanie                                               2021AGUFMSM51C..06H
# Howard, Stephanie K.                                            2022AGUFMSM25A..05H
# Hubbard, Ryan J.                                                2016AAS...22733403H
# Huber, Tito E.                    2001stai.conf.1113H, 2001AIPC..552.1113H, 10.1...
# Hughes, Andréa. C. G.                     10.1029/2023JA031838, 2023JGRA..12831838H
# Hübsch, Tristan                   arXiv:1202.4342, 10.1142/S0217751X12501734, 10...
# Jenkins, G. S.                                                  2004AGUSM.U22A..05J
# Jenkins, Gregory S.               2012GeoRL..3920810J, 10.1029/2012GL053532, 200...
# Lewis, J. M. T.                           2021JGRE..12606803L, 10.1029/2020JE006803
# Lindesay, James                   2011arXiv1108.4897L, 10.1007/s10701-012-9684-2...
# Mann, Ayanna                                                    2023AAS...24120511M
# Manning, Sinclaire                         2015AAS...22514338M, 2013AAS...22144203M
# Mbaye, Mamadou Thiao                                            2014PhDT.......274M
# McGee, Carissma                                                 2023AAS...24117763M
# Mensah, Francis Emmanuel Tofodji                                2007PhDT........23M
# Misra, P.                                                       2012AGUFM.P13A1893M
# Moore, H.                                                       2002AGUSM.A22B..11M
# Morse, Z.                                                       2020AGUFMP063...02M
# Morse, Zachary R.                           10.3847/PSJ/ac0728, 2021PSJ.....2..167M
# N'Doumi, M.                                                     2011AGUFM.P33A1750N
# Ohi, Seigo                                   2004AIPC..699..938O, 10.1063/1.1649659
# Olsen, K.                                                       2020AGUFMP086...02O
# Pope, Myles                                                     2023AAS...24140126P
# Qasim, Danna                      10.3847/1538-4357/ac602b, 2022ApJ...929..176Q,...
# Reynolds, M. A.                   2001JATP...63.1267R, 10.1016/S1364-6826(00)002...
# Roi Smith, Sergio                                               2017AAS...22924203R
# Sakai, R. K.                                                    2011AGUFM.A41A0032S
# Schwartzman, D. W.                2014AGUFM.P11C3775S, 10.1016/j.gca.2006.06.104...
# Schwartzman, David                2011OLEB..tmp...41S, 2011OLEB...41..581S, 10.1...
# Strong, Avaine                                                  2000PhDT.......340S
# Thomas, Brianna P.                2017AAS...22943501T, 2016AAS...22713819T, 2015...
# Thorpe, A. N.                     2002M&PS...37..763T, 10.1111/j.1945-5100.2002....
# Vidaurri, Monica R.               2022PSJ.....3..137V, 10.3847/PSJ/ac68e2, arXiv...
# Walker, Ashley                    2023AAS...24110401W, 2023AAS...24116201W, 2022...
# Weber, Tristan                            10.1029/2022GL098633, 2022GeoRL..4998633W
# Whiteman, D. N.                                                 2020AGUFMED005..05W
# Wofford, A.                                2021AAS...23753511W, 2020AAS...23537712W
# Yarber, Aara'L.                            2015AAS...22525022Y, 2014AAS...22325219Y
#
#                                                                        Top 10 Words  \
# Input Author
# Abdullah, Ajamu                   [('star', 5), ('system', 3), ('merging', 3), (...
# Allen, Walter W., Jr.             [('equation', 6), ('formulation', 5), ('proper...
# Anusie, Steve                     [('star', 9), ('flare', 5), ('observation', 5)...
# Bacha, Tulu                       [('wind', 10), ('error', 10), ('glow', 9), ('c...
# Blake, Ameer                      [('star', 6), ('cubesat', 6), ('disk', 4), ('p...
# Brown, Beth A.                    [('black', 4), ('hole', 4), ('diagram', 3), ('...
# Coley, J. B.                      [('ray', 6), ('xmm', 4), ('newton', 4), ('tele...
# Coley, Joel                       [('nustar', 10), ('kev', 10), ('luminosity', 1...
# Coley, Joel B.                    [('superorbital', 22), ('ray', 11), ('minimum'...
# David-Uraz, A.                    [('star', 8), ('magnetic', 7), ('field', 6), (...
# Dumervil, S.                      [('europa', 9), ('ocean', 3), ('electrical', 3...
# Fahr, A.                          [('radical', 7), ('reaction', 6), ('product', ...
# Finch, Tehani K.                  [('image', 5), ('supertube', 4), ('magnificati...
# Fletcher, Alex                    [('structure', 5), ('management', 4), ('public...
# Garcia-Sanchez, Raul F.           [('gas', 10), ('temperature', 7), ('oxide', 6)...
# Halpern, J. B.                    [('radical', 8), ('reaction', 8), ('pressure',...
# Howard, S. K.                     [('wave', 9), ('solar', 6), ('wind', 6), ('mag...
# Howard, Stephanie                 [('triton', 8), ('feature', 7), ('neptune', 5)...
# Howard, Stephanie K.              [('event', 5), ('disturbance', 4), ('martian',...
# Hubbard, Ryan J.                  [('galaxy', 7), ('edig', 5), ('gas', 3), ('sta...
# Huber, Tito E.                    [('bi', 6), ('thermoelectric', 6), ('composite...
# Hughes, Andréa. C. G.             [('model', 16), ('proton', 6), ('aurora', 6), ...
# Hübsch, Tristan                   [('adinkras', 4), ('supermultiplets', 3), ('ga...
# Jenkins, G. S.                    [('high', 5), ('condition', 4), ('obliquity', ...
# Jenkins, Gregory S.               [('sal', 13), ('tropical', 10), ('ozone', 9), ...
# Lewis, J. M. T.                   [('organic', 7), ('acetate', 6), ('salt', 5), ...
# Lindesay, James                   [('quantum', 17), ('coordinate', 8), ('gravita...
# Mann, Ayanna                      [('element', 6), ('optical', 4), ('ztf', 4), (...
# Manning, Sinclaire                [('galaxy', 10), ('sample', 6), ('observed', 6...
# Mbaye, Mamadou Thiao              [('adsorption', 6), ('gas', 5), ('nanotube', 5...
# McGee, Carissma                   [('stream', 10), ('gd', 6), ('stellar', 5), ('...
# Mensah, Francis Emmanuel Tofodji  [('system', 7), ('ft', 5), ('water', 4), ('vap...
# Misra, P.                         [('library', 12), ('spectrum', 5), ('sam', 4),...
# Moore, H.                         [('interaction', 6), ('shape', 5), ('volume', ...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [('lunar', 9), ('basin', 5), ('mission', 5), (...
# N'Doumi, M.                       [('nh', 9), ('state', 6), ('radiative', 6), ('...
# Ohi, Seigo                        [('hsct', 7), ('space', 5), ('muscle', 5), ('h...
# Olsen, K.                         [('ice', 12), ('rift', 10), ('stress', 7), ('s...
# Pope, Myles                       [('star', 6), ('mass', 5), ('red', 3), ('giant...
# Qasim, Danna                      [('exchange', 6), ('ice', 5), ('rate', 5), ('c...
# Reynolds, M. A.                   [('density', 8), ('ion', 6), ('time', 6), ('va...
# Roi Smith, Sergio                 [('pulsar', 7), ('timing', 6), ('model', 3), (...
# Sakai, R. K.                      [('ozone', 10), ('day', 6), ('layer', 5), ('ba...
# Schwartzman, D. W.                [('bew', 4), ('temperature', 4), ('earth', 4),...
# Schwartzman, David                [('temperature', 6), ('path', 5), ('encephaliz...
# Strong, Avaine                    [('spacecraft', 10), ('relative', 4), ('mainta...
# Thomas, Brianna P.                [('star', 10), ('source', 8), ('planet', 6), (...
# Thorpe, A. N.                     [('magnetization', 3), ('coercive', 3), ('tagi...
# Vidaurri, Monica R.               [('venus', 11), ('zone', 8), ('planet', 6), ('...
# Walker, Ashley                    [('aerosol', 21), ('ice', 12), ('giant', 12), ...
# Weber, Tristan                    [('ganymede', 4), ('data', 3), ('magnetic', 3)...
# Whiteman, D. N.                   [('workshop', 10), ('virtual', 4), ('week', 3)...
# Wofford, A.                       [('radio', 9), ('flare', 6), ('star', 5), ('ar...
# Yarber, Aara'L.                   [('bar', 6), ('galaxy', 5), ('data', 5), ('sta...
#
#                                                                      Top 10 Bigrams  \
# Input Author
# Abdullah, Ajamu                   [(('star', 'formation'), 3), (('ngc', 'system'...
# Allen, Walter W., Jr.             [(('proper', 'time'), 5), (('canonical', 'prop...
# Anusie, Steve                     [(('light', 'curve'), 4), (('dwarf', 'star'), ...
# Bacha, Tulu                       [(('wind', 'speed'), 4), (('atmospheric', 'var...
# Blake, Ameer                      [(('debris', 'disk'), 2), (('beta', 'pic'), 2)...
# Brown, Beth A.                    [(('black', 'hole'), 4), (('large', 'scale'), ...
# Coley, J. B.                      [(('xmm', 'newton'), 4), (('light', 'curve'), ...
# Coley, Joel                       [(('nicer', 'nustar'), 6), (('neutron', 'star'...
# Coley, Joel B.                    [(('superorbital', 'modulation'), 8), (('minim...
# David-Uraz, A.                    [(('magnetic', 'field'), 4), (('dipolar', 'mag...
# Dumervil, S.                      [(('electrical', 'conductivity'), 3), (('magne...
# Fahr, A.                          [(('radical', 'reaction'), 3), (('relevant', '...
# Finch, Tehani K.                  [(('black', 'hole'), 2), (('angular', 'momentu...
# Fletcher, Alex                    [(('internet', 'search'), 2), (('search', 'eng...
# Garcia-Sanchez, Raul F.           [(('metal', 'oxide'), 5), (('temperature', 'in...
# Halpern, J. B.                    [(('radical', 'reaction'), 5), (('torr', 'kpa'...
# Howard, S. K.                     [(('solar', 'wind'), 6), (('magnetic', 'field'...
# Howard, Stephanie                 [(('neptune', 'magnetosphere'), 2), (('resonan...
# Howard, Stephanie K.              [(('magnetic', 'field'), 4), (('martian', 'mag...
# Hubbard, Ryan J.                  [(('accretion', 'feedback'), 2), (('feedback',...
# Huber, Tito E.                    [(('bi', 'sb'), 2), (('thermoelectric', 'perfo...
# Hughes, Andréa. C. G.             [(('proton', 'aurora'), 5), (('model', 'compar...
# Hübsch, Tristan                   [(('gauge', 'quotient'), 3), (('doran', 'al'),...
# Jenkins, G. S.                    [(('proterozoic', 'era'), 3), (('high', 'obliq...
# Jenkins, Gregory S.               [(('ozone', 'mixing'), 5), (('mixing', 'ratio'...
# Lewis, J. M. T.                   [(('organic', 'salt'), 4), (('ca', 'mg'), 3), ...
# Lindesay, James                   [(('black', 'hole'), 6), (('gravitating', 'qua...
# Mann, Ayanna                      [(('large', 'optical'), 2), (('optical', 'surv...
# Manning, Sinclaire                [(('mg', 'ii'), 3), (('star', 'cluster'), 3), ...
# Mbaye, Mamadou Thiao              [(('carbon', 'nanotube'), 2), (('explore', 'ad...
# McGee, Carissma                   [(('stellar', 'stream'), 5), (('dark', 'matter...
# Mensah, Francis Emmanuel Tofodji  [(('water', 'vapor'), 4), (('ft', 'ft'), 4), (...
# Misra, P.                         [(('normalization', 'protocol'), 3), (('gcms',...
# Moore, H.                         [(('interaction', 'volume'), 5), (('laser', 'b...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [(('schr', 'dinger'), 4), (('dinger', 'basin')...
# N'Doumi, M.                       [(('radiative', 'lifetime'), 6), (('electronic...
# Ohi, Seigo                        [(('muscle', 'loss'), 3), (('loss', 'immunodef...
# Olsen, K.                         [(('ice', 'shelf'), 6), (('stress', 'release')...
# Pope, Myles                       [(('red', 'giant'), 3), (('giant', 'star'), 3)...
# Qasim, Danna                      [(('rate', 'constant'), 5), (('constant', 'exc...
# Reynolds, M. A.                   [(('local', 'time'), 4), (('helium', 'ion'), 3...
# Roi Smith, Sergio                 [(('timing', 'model'), 3), (('model', 'provide...
# Sakai, R. K.                      [(('ozonesonde', 'tethered'), 2), (('tethered'...
# Schwartzman, D. W.                [(('geologic', 'time'), 2), (('long', 'term'),...
# Schwartzman, David                [(('path', 'encephalization'), 2), (('homeothe...
# Strong, Avaine                    [(('constellation', 'station'), 3), (('station...
# Thomas, Brianna P.                [(('host', 'star'), 3), (('debris', 'disk'), 2...
# Thorpe, A. N.                     [(('tagish', 'lake'), 3), (('multi', 'domain')...
# Vidaurri, Monica R.               [(('habitable', 'zone'), 4), (('venus', 'zone'...
# Walker, Ashley                    [(('ice', 'giant'), 12), (('aerosol', 'layer')...
# Weber, Tristan                    [(('internal', 'magnetic'), 2), (('dipole', 'a...
# Whiteman, D. N.                   [(('fully', 'virtual'), 2), (('virtual', 'expe...
# Wofford, A.                       [(('optical', 'flare'), 3), (('broader', 'impa...
# Yarber, Aara'L.                   [(('star', 'formation'), 5), (('million', 'yea...
#
#                                                                     Top 10 Trigrams  \
# Input Author
# Abdullah, Ajamu                   [(('ngc', 'system', 'merging'), 1), (('system'...
# Allen, Walter W., Jr.             [(('canonical', 'proper', 'time'), 4), (('rese...
# Anusie, Steve                     [(('muscles', 'treasury', 'survey'), 2), (('as...
# Bacha, Tulu                       [(('goddard', 'lidar', 'observatory'), 2), (('...
# Blake, Ameer                      [(('goal', 'project', 'growing'), 1), (('proje...
# Brown, Beth A.                    [(('large', 'scale', 'causal'), 2), (('black',...
# Coley, J. B.                      [(('report', 'xmm', 'newton'), 1), (('xmm', 'n...
# Coley, Joel                       [(('fe', 'fluorescent', 'emission'), 4), (('re...
# Coley, Joel B.                    [(('superorbital', 'minimum', 'maximum'), 6), ...
# David-Uraz, A.                    [(('dipolar', 'magnetic', 'field'), 2), (('res...
# Dumervil, S.                      [(('electrical', 'conductivity', 'data'), 2), ...
# Fahr, A.                          [(('previously', 'studied', 'kinetics'), 1), (...
# Finch, Tehani K.                  [(('low', 'velocity', 'scattering'), 1), (('ve...
# Fletcher, Alex                    [(('internet', 'search', 'engines'), 2), (('pu...
# Garcia-Sanchez, Raul F.           [(('metal', 'oxide', 'gas'), 2), (('wo', 'sili...
# Halpern, J. B.                    [(('large', 'hydrocarbon', 'molecules'), 1), (...
# Howard, S. K.                     [(('ultra', 'low', 'frequency'), 2), (('low', ...
# Howard, Stephanie                 [(('august', 'voyager', 'spacecraft'), 1), (('...
# Howard, Stephanie K.              [(('martian', 'magnetosphere', 'due'), 2), (('...
# Hubbard, Ryan J.                  [(('accretion', 'feedback', 'processes'), 2), ...
# Huber, Tito E.                    [(('bulk', 'bi', 'semimetal'), 1), (('bi', 'se...
# Hughes, Andréa. C. G.             [(('martian', 'proton', 'aurora'), 2), (('mode...
# Hübsch, Tristan                   [(('recent', 'efforts', 'classify'), 1), (('ef...
# Jenkins, G. S.                    [(('results', 'gcm', 'simulations'), 1), (('gc...
# Jenkins, Gregory S.               [(('ozone', 'mixing', 'ratios'), 3), (('middle...
# Lewis, J. M. T.                   [(('organic', 'salts', 'fe'), 1), (('salts', '...
# Lindesay, James                   [(('geometries', 'horizons', 'offer'), 2), (('...
# Mann, Ayanna                      [(('large', 'optical', 'surveys'), 2), (('wide...
# Manning, Sinclaire                [(('star', 'formation', 'induced'), 2), (('rot...
# Mbaye, Mamadou Thiao              [(('consequence', 'heat', 'capacity'), 2), (('...
# McGee, Carissma                   [(('gd', 'stellar', 'stream'), 2), (('longest'...
# Mensah, Francis Emmanuel Tofodji  [(('ft', 'ft', 'ft'), 3), (('water', 'vapor', ...
# Misra, P.                         [(('library', 'mass', 'spectra'), 1), (('mass'...
# Moore, H.                         [(('temporal', 'shape', 'returned'), 2), (('si...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [(('schr', 'dinger', 'basin'), 3), (('dinger',...
# N'Doumi, M.                       [(('electronically', 'excited', 'state'), 3), ...
# Ohi, Seigo                        [(('astronauts', 'experience', 'severe'), 1), ...
# Olsen, K.                         [(('enceladus', 'tiger', 'stripe'), 2), (('tig...
# Pope, Myles                       [(('red', 'giant', 'stars'), 3), (('mass', 'ra...
# Qasim, Danna                      [(('rate', 'constants', 'exchange'), 2), (('ga...
# Reynolds, M. A.                   [(('helium', 'ion', 'density'), 2), (('local',...
# Roi Smith, Sergio                 [(('timing', 'models', 'provide'), 2), (('mode...
# Sakai, R. K.                      [(('ozonesonde', 'tethered', 'balloon'), 2), (...
# Schwartzman, D. W.                [(('submit', 'tightly', 'coupled'), 1), (('tig...
# Schwartzman, David                [(('propose', 'consideration', 'evolutionary')...
# Strong, Avaine                    [(('constellation', 'station', 'keeping'), 3),...
# Thomas, Brianna P.                [(('percent', 'frequency', 'sources'), 2), (('...
# Thorpe, A. N.                     [(('tagish', 'lake', 'meteorite'), 2), (('mult...
# Vidaurri, Monica R.               [(('outer', 'edge', 'venus'), 2), (('edge', 'v...
# Walker, Ashley                    [(('atmospheric', 'composition', 'ice'), 3), (...
# Weber, Tristan                    [(('study', 'data', 'juno'), 1), (('data', 'ju...
# Whiteman, D. N.                   [(('fully', 'virtual', 'experience'), 2), (('f...
# Wofford, A.                       [(('radio', 'bursts', 'optical'), 2), (('burst...
# Yarber, Aara'L.                   [(('band', 'vla', 'continuum'), 1), (('vla', '...
#
#                                                           Data Type
# Input Author
# Abdullah, Ajamu                                               Clean
# Allen, Walter W., Jr.                                         Dirty
# Anusie, Steve                                                 Clean
# Bacha, Tulu                                                   Dirty
# Blake, Ameer                                                  Clean
# Brown, Beth A.                                         Dirty, Dirty
# Coley, J. B.                                                  Clean
# Coley, Joel                                            Clean, Dirty
# Coley, Joel B.                                  Clean, Clean, Clean
# David-Uraz, A.                                         Clean, Clean
# Dumervil, S.                                                  Dirty
# Fahr, A.                                                      Dirty
# Finch, Tehani K.                                       Dirty, Clean
# Fletcher, Alex                                                Clean
# Garcia-Sanchez, Raul F.                                       Dirty
# Halpern, J. B.                                                Dirty
# Howard, S. K.                                                 Dirty
# Howard, Stephanie                                             Dirty
# Howard, Stephanie K.                                          Dirty
# Hubbard, Ryan J.                                              Clean
# Huber, Tito E.                                                Dirty
# Hughes, Andréa. C. G.                                         Dirty
# Hübsch, Tristan                                        Dirty, Dirty
# Jenkins, G. S.                                                Dirty
# Jenkins, Gregory S.               Dirty, Dirty, Dirty, Dirty, Dirty
# Lewis, J. M. T.                                               Dirty
# Lindesay, James                   Dirty, Dirty, Dirty, Dirty, Dirty
# Mann, Ayanna                                                  Clean
# Manning, Sinclaire                                     Clean, Clean
# Mbaye, Mamadou Thiao                                          Dirty
# McGee, Carissma                                               Clean
# Mensah, Francis Emmanuel Tofodji                              Dirty
# Misra, P.                                                     Dirty
# Moore, H.                                                     Dirty
# Morse, Z.                                                     Dirty
# Morse, Zachary R.                                             Dirty
# N'Doumi, M.                                                   Dirty
# Ohi, Seigo                                                    Dirty
# Olsen, K.                                                     Dirty
# Pope, Myles                                                   Clean
# Qasim, Danna                                                  Clean
# Reynolds, M. A.                                        Dirty, Dirty
# Roi Smith, Sergio                                             Clean
# Sakai, R. K.                                                  Dirty
# Schwartzman, D. W.                                     Dirty, Dirty
# Schwartzman, David                              Dirty, Dirty, Dirty
# Strong, Avaine                                                Dirty
# Thomas, Brianna P.                              Clean, Clean, Clean
# Thorpe, A. N.                                                 Dirty
# Vidaurri, Monica R.                                           Dirty
# Walker, Ashley                           Clean, Clean, Dirty, Dirty
# Weber, Tristan                                                Dirty
# Whiteman, D. N.                                               Dirty
# Wofford, A.                                            Clean, Clean
# Yarber, Aara'L.                                        Clean, Clean

# %% [markdown]
# **Locate arXiv identifiers for papers**
#
# For proof of functionality, we choose to focus on arXiv published papers, due to the easy to navigate API of arXiv. The identifier is pulled so that the pdf can be easily downloaded. Future work includes expanding on publication websites we pull from.

# %%
target = r'arXiv:(\S+)'

def process_row_id(row):
  identifiers = row['Identifier'].split(',')
  arXiv_list = []

  for identifier in identifiers:
    match = re.search(target, identifier)
    if match:
      arXiv = match.group(1)
      arXiv_list.append(arXiv)
    else:
      arXiv_list.append(None)
  if any(arXiv_list):
    return ', '.join(str(x) for x in arXiv_list if x is not None)
  else:
    return 'None'

datf['arxiv-id'] = datf.apply(process_row_id, axis = 1)
datf
# Out:
#                                                                   Input Institution  \
# Input Author
# Abdullah, Ajamu                                                   Howard University
# Allen, Walter W., Jr.                                             Howard University
# Anusie, Steve                                                     Howard University
# Bacha, Tulu                                                       Howard University
# Blake, Ameer                                                      Howard University
# Brown, Beth A.                                 Howard University, Howard University
# Coley, J. B.                                                      Howard University
# Coley, Joel                                    Howard University, Howard University
# Coley, Joel B.                    Howard University, Howard University, Howard U...
# David-Uraz, A.                                 Howard University, Howard University
# Dumervil, S.                                                      Howard University
# Fahr, A.                                                          Howard University
# Finch, Tehani K.                               Howard University, Howard University
# Fletcher, Alex                                                    Howard University
# Garcia-Sanchez, Raul F.                                           Howard University
# Halpern, J. B.                                                    Howard University
# Howard, S. K.                                                     Howard University
# Howard, Stephanie                                                 Howard University
# Howard, Stephanie K.                                              Howard University
# Hubbard, Ryan J.                                                  Howard University
# Huber, Tito E.                                                    Howard University
# Hughes, Andréa. C. G.                                             Howard University
# Hübsch, Tristan                                Howard University, Howard University
# Jenkins, G. S.                                                    Howard University
# Jenkins, Gregory S.               Howard University, Howard University, Howard U...
# Lewis, J. M. T.                                                   Howard University
# Lindesay, James                   Howard University, Howard University, Howard U...
# Mann, Ayanna                                                      Howard University
# Manning, Sinclaire                             Howard University, Howard University
# Mbaye, Mamadou Thiao                                              Howard University
# McGee, Carissma                                                   Howard University
# Mensah, Francis Emmanuel Tofodji                                  Howard University
# Misra, P.                                                         Howard University
# Moore, H.                                                         Howard University
# Morse, Z.                                                         Howard University
# Morse, Zachary R.                                                 Howard University
# N'Doumi, M.                                                       Howard University
# Ohi, Seigo                                                        Howard University
# Olsen, K.                                                         Howard University
# Pope, Myles                                                       Howard University
# Qasim, Danna                                                      Howard University
# Reynolds, M. A.                                Howard University, Howard University
# Roi Smith, Sergio                                                 Howard University
# Sakai, R. K.                                                      Howard University
# Schwartzman, D. W.                             Howard University, Howard University
# Schwartzman, David                Howard University, Howard University, Howard U...
# Strong, Avaine                                                    Howard University
# Thomas, Brianna P.                Howard University, Howard University, Howard U...
# Thorpe, A. N.                                                     Howard University
# Vidaurri, Monica R.                                               Howard University
# Walker, Ashley                    Howard University, Howard University, Howard U...
# Weber, Tristan                                                    Howard University
# Whiteman, D. N.                                                   Howard University
# Wofford, A.                                    Howard University, Howard University
# Yarber, Aara'L.                                Howard University, Howard University
#
#                                                                        First Author  \
# Input Author
# Abdullah, Ajamu                                                     Abdullah, Ajamu
# Allen, Walter W., Jr.                                         Allen, Walter W., Jr.
# Anusie, Steve                                                         Anusie, Steve
# Bacha, Tulu                                                             Bacha, Tulu
# Blake, Ameer                                                           Blake, Ameer
# Brown, Beth A.                                       Brown, Beth A., Brown, Beth A.
# Coley, J. B.                                                           Coley, J. B.
# Coley, Joel                                                Coley, Joel, Coley, Joel
# Coley, Joel B.                       Coley, Joel B., Coley, Joel B., Coley, Joel B.
# David-Uraz, A.                                       David-Uraz, A., David-Uraz, A.
# Dumervil, S.                                                           Dumervil, S.
# Fahr, A.                                                                   Fahr, A.
# Finch, Tehani K.                                 Finch, Tehani K., Finch, Tehani K.
# Fletcher, Alex                                                       Fletcher, Alex
# Garcia-Sanchez, Raul F.                                     Garcia-Sanchez, Raul F.
# Halpern, J. B.                                                       Halpern, J. B.
# Howard, S. K.                                                         Howard, S. K.
# Howard, Stephanie                                                 Howard, Stephanie
# Howard, Stephanie K.                                           Howard, Stephanie K.
# Hubbard, Ryan J.                                                   Hubbard, Ryan J.
# Huber, Tito E.                                                       Huber, Tito E.
# Hughes, Andréa. C. G.                                         Hughes, Andréa. C. G.
# Hübsch, Tristan                                    Hübsch, Tristan, Hübsch, Tristan
# Jenkins, G. S.                                                       Jenkins, G. S.
# Jenkins, Gregory S.               Jenkins, Gregory S., Jenkins, Gregory S., Jenk...
# Lewis, J. M. T.                                                     Lewis, J. M. T.
# Lindesay, James                   Lindesay, James, Lindesay, James, Lindesay, Ja...
# Mann, Ayanna                                                           Mann, Ayanna
# Manning, Sinclaire                           Manning, Sinclaire, Manning, Sinclaire
# Mbaye, Mamadou Thiao                                           Mbaye, Mamadou Thiao
# McGee, Carissma                                                     McGee, Carissma
# Mensah, Francis Emmanuel Tofodji                   Mensah, Francis Emmanuel Tofodji
# Misra, P.                                                                 Misra, P.
# Moore, H.                                                                 Moore, H.
# Morse, Z.                                                                 Morse, Z.
# Morse, Zachary R.                                                 Morse, Zachary R.
# N'Doumi, M.                                                             N'Doumi, M.
# Ohi, Seigo                                                               Ohi, Seigo
# Olsen, K.                                                                 Olsen, K.
# Pope, Myles                                                             Pope, Myles
# Qasim, Danna                                                           Qasim, Danna
# Reynolds, M. A.                                    Reynolds, M. A., Reynolds, M. A.
# Roi Smith, Sergio                                                 Roi Smith, Sergio
# Sakai, R. K.                                                           Sakai, R. K.
# Schwartzman, D. W.                           Schwartzman, D. W., Schwartzman, D. W.
# Schwartzman, David                Schwartzman, David, Schwartzman, David, Schwar...
# Strong, Avaine                                                       Strong, Avaine
# Thomas, Brianna P.                Thomas, Brianna P., Thomas, Brianna P., Thomas...
# Thorpe, A. N.                                                         Thorpe, A. N.
# Vidaurri, Monica R.                                             Vidaurri, Monica R.
# Walker, Ashley                    Walker, Ashley, Walker, Ashley, Walker, Ashley...
# Weber, Tristan                                                       Weber, Tristan
# Whiteman, D. N.                                                     Whiteman, D. N.
# Wofford, A.                                                Wofford, A., Wofford, A.
# Yarber, Aara'L.                                    Yarber, Aara'L., Yarber, Aara'L.
#
#                                                                             Bibcode  \
# Input Author
# Abdullah, Ajamu                                                 2014AAS...22324403A
# Allen, Walter W., Jr.                                           2009PhDT.........1A
# Anusie, Steve                                                   2019AAS...23325917A
# Bacha, Tulu                                                     2011PhDT.........7B
# Blake, Ameer                                                    2016AAS...22713710B
# Brown, Beth A.                            2010AIPC.1280....3B,\n2008CQGra..25j5026B
# Coley, J. B.                                                    2020AAS...23545701C
# Coley, Joel                               2023AAS...24142807C,\n2022HEAD...1940601C
# Coley, Joel B.                    2019ApJ...879...34C,\n2019AAS...23323601C,\n20...
# David-Uraz, A.                            2021MNRAS.504.4841D,\n2021MNRAS.501.2677D
# Dumervil, S.                                                    2020AGUFMP076.0002D
# Fahr, A.                                                        2011epsc.conf...11F
# Finch, Tehani K.                          2009JHEP...03..145F,\n2002ApJ...577...51F
# Fletcher, Alex                                                  2004SPIE.5371..195F
# Garcia-Sanchez, Raul F.                                         2014isms.confEMJ07G
# Halpern, J. B.                                                  2011AGUFM.P13A1645H
# Howard, S. K.                                                   2020AGUFMU008...06H
# Howard, Stephanie                                               2021AGUFMSM51C..06H
# Howard, Stephanie K.                                            2022AGUFMSM25A..05H
# Hubbard, Ryan J.                                                2016AAS...22733403H
# Huber, Tito E.                                                  2001AIPC..552.1113H
# Hughes, Andréa. C. G.                                           2023JGRA..12831838H
# Hübsch, Tristan                           2012IJMPA..2750173H,\n2005ppu..conf..261H
# Jenkins, G. S.                                                  2004AGUSM.U22A..05J
# Jenkins, Gregory S.               2012GeoRL..3920810J,\n2008GeoRL..3512806J,\n20...
# Lewis, J. M. T.                                                 2021JGRE..12606803L
# Lindesay, James                   2012FoPh...42.1573L,\n2010CQGra..27u5015L,\n20...
# Mann, Ayanna                                                    2023AAS...24120511M
# Manning, Sinclaire                        2015AAS...22514338M,\n2013AAS...22144203M
# Mbaye, Mamadou Thiao                                            2014PhDT.......274M
# McGee, Carissma                                                 2023AAS...24117763M
# Mensah, Francis Emmanuel Tofodji                                2007PhDT........23M
# Misra, P.                                                       2012AGUFM.P13A1893M
# Moore, H.                                                       2002AGUSM.A22B..11M
# Morse, Z.                                                       2020AGUFMP063...02M
# Morse, Zachary R.                                               2021PSJ.....2..167M
# N'Doumi, M.                                                     2011AGUFM.P33A1750N
# Ohi, Seigo                                                      2004AIPC..699..938O
# Olsen, K.                                                       2020AGUFMP086...02O
# Pope, Myles                                                     2023AAS...24140126P
# Qasim, Danna                                                    2022ApJ...929..176Q
# Reynolds, M. A.                           2001JASTP..63.1267R,\n2001AGUSM..SM52D07R
# Roi Smith, Sergio                                               2017AAS...22924203R
# Sakai, R. K.                                                    2011AGUFM.A41A0032S
# Schwartzman, D. W.                        2014AGUFM.P11C3775S,\n2006GeCAS..70Q.567S
# Schwartzman, David                2011OLEB...41..581S,\n2008AsBio...8..187S,\n20...
# Strong, Avaine                                                  2000PhDT.......340S
# Thomas, Brianna P.                2017AAS...22943501T,\n2016AAS...22713819T,\n20...
# Thorpe, A. N.                                                   2002M&PS...37..763T
# Vidaurri, Monica R.                                             2022PSJ.....3..137V
# Walker, Ashley                    2023AAS...24110401W,\n2023AAS...24116201W,\n20...
# Weber, Tristan                                                  2022GeoRL..4998633W
# Whiteman, D. N.                                                 2020AGUFMED005..05W
# Wofford, A.                               2021AAS...23753511W,\n2020AAS...23537712W
# Yarber, Aara'L.                           2015AAS...22525022Y,\n2014AAS...22325219Y
#
#                                                                               Title  \
# Input Author
# Abdullah, Ajamu                                      New Star Formation in NGC 3690
# Allen, Walter W., Jr.             The canonical proper-time theory applied to pa...
# Anusie, Steve                     The Mini-MUSCLES Treasury Survey: Measurements...
# Bacha, Tulu                       Effects of Cloud on Goddard Lidar Observatory ...
# Blake, Ameer                      A CubeSat to Search for Transiting Planets Aro...
# Brown, Beth A.                    Causal Structures of Dynamic Black Holes, Cons...
# Coley, J. B.                      A Study of the Extragalactic Gamma-ray Binary ...
# Coley, Joel                       A Study of the 2020 Type II Giant Outburst of ...
# Coley, Joel B.                    A Study of the 20 day Superorbital Modulation ...
# David-Uraz, A.                    MOBSTER - IV. Detection of a new magnetic B-ty...
# Dumervil, S.                      Electrical Conductivity and Magnetic Induction...
# Fahr, A.                          Pressure Effects on Product Channels of Hydroc...
# Finch, Tehani K.                  Three-charge supertubes in a rotating black ho...
# Fletcher, Alex                    Toward public volume database management: a ca...
# Garcia-Sanchez, Raul F.           Distinctions in the Raman Spectroscopy Feature...
# Halpern, J. B.                    Pressure Effects on Product Channels of the Al...
# Howard, S. K.                     Characteristics of Ultra Low Frequency Plasma ...
# Howard, Stephanie                 Voyager 2 Magnetic Field Data Near Closest App...
# Howard, Stephanie K.              Current State of a Magnetospheric Disturbance ...
# Hubbard, Ryan J.                  Identifying Extraplanar Diffuse Ionized Gas in...
# Huber, Tito E.                    Thermomagnetic coolers based on Bi and Bi-Sb n...
# Hughes, Andréa. C. G.             Advancing Our Understanding of Martian Proton ...
# Hübsch, Tristan                   On the Construction and the Structure of Off-S...
# Jenkins, G. S.                    High obliquity simulations of Proterozoic clim...
# Jenkins, Gregory S.               The influence of the SAL and lightning on trop...
# Lewis, J. M. T.                   Pyrolysis of Oxalate, Acetate, and Perchlorate...
# Lindesay, James                   Self-consistent Solutions of Canonical Proper ...
# Mann, Ayanna                      Improved Model Of Optical Elements Involved In...
# Manning, Sinclaire                Probing the Magnetic Fields in the Environment...
# Mbaye, Mamadou Thiao                        Adsorption of Gases on Carbon Nanotubes
# McGee, Carissma                   Dark Matter Accounts for Perturbation in the G...
# Mensah, Francis Emmanuel Tofodji  Use of the selected overlap LIDAR experiment (...
# Misra, P.                         Organic Contaminants Library for the Sample An...
# Moore, H.                         Analysis of the Temporal Characteristics of th...
# Morse, Z.                         Developing AN Augmented Reality Application fo...
# Morse, Zachary R.                 Detailed Morphologic Mapping and Traverse Plan...
# N'Doumi, M.                       Radiative Lifetimes of\nNH<SUB>2</SUB>(\Atilde...
# Ohi, Seigo                        The Hematopoietic Stem Cell Therapy for Explor...
# Olsen, K.                         Deformation along Enceladus' Tiger Stripes: In...
# Pope, Myles                             Accurate Masses of Extraordinary Red Giants
# Qasim, Danna                      Radiation-induced D/H Exchange Rate Constants ...
# Reynolds, M. A.                   Equatorial coupling between the plasmasphere a...
# Roi Smith, Sergio                      Long-Term Timing of Globular Cluster Pulsars
# Sakai, R. K.                      Ozone Development and Destruction in the Plane...
# Schwartzman, D. W.                Habitability for Complex Life and the Developm...
# Schwartzman, David                Multiple Paths to Encephalization and Technica...
# Strong, Avaine                    On the deployment and station keeping dynamics...
# Thomas, Brianna P.                Revisiting the Trend of Debris Disks with rega...
# Thorpe, A. N.                     Magnetic study of magnetite in the Tagish Lake...
# Vidaurri, Monica R.               The Outer Edge of the Venus Zone around Main-s...
# Walker, Ashley                    Modeling Cloud Microphysics in Ice Giant Atmos...
# Weber, Tristan                    Updated Spherical Harmonic Magnetic Field Mome...
# Whiteman, D. N.                   Planetary Boundary Layer Workshop in the Time ...
# Wofford, A.                       Towards the development of a STEAM rural broad...
# Yarber, Aara'L.                   Mapping the Star Formation in NGC 1097 Using t...
#
#                                                                    Publication Date  \
# Input Author
# Abdullah, Ajamu                                                          2014-01-00
# Allen, Walter W., Jr.                                                    2009-00-00
# Anusie, Steve                                                            2019-01-00
# Bacha, Tulu                                                              2011-00-00
# Blake, Ameer                                                             2016-01-00
# Brown, Beth A.                                               2010-10-00, 2008-05-00
# Coley, J. B.                                                             2020-01-00
# Coley, Joel                                                  2023-01-00, 2022-04-00
# Coley, Joel B.                                   2019-07-00, 2019-01-00, 2019-01-00
# David-Uraz, A.                                               2021-07-00, 2021-02-00
# Dumervil, S.                                                             2020-12-00
# Fahr, A.                                                                 2011-10-00
# Finch, Tehani K.                                             2009-03-00, 2002-09-00
# Fletcher, Alex                                                           2004-04-00
# Garcia-Sanchez, Raul F.                                                  2014-06-00
# Halpern, J. B.                                                           2011-12-00
# Howard, S. K.                                                            2020-12-00
# Howard, Stephanie                                                        2021-12-00
# Howard, Stephanie K.                                                     2022-12-00
# Hubbard, Ryan J.                                                         2016-01-00
# Huber, Tito E.                                                           2001-02-00
# Hughes, Andréa. C. G.                                                    2023-10-00
# Hübsch, Tristan                                              2012-11-00, 2005-00-00
# Jenkins, G. S.                                                           2004-05-00
# Jenkins, Gregory S.               2012-10-00, 2008-06-00, 2008-06-00, 2008-04-00...
# Lewis, J. M. T.                                                          2021-04-00
# Lindesay, James                   2012-12-00, 2010-11-00, 2010-10-00, 2009-06-00...
# Mann, Ayanna                                                             2023-01-00
# Manning, Sinclaire                                           2015-01-00, 2013-01-00
# Mbaye, Mamadou Thiao                                                     2014-01-00
# McGee, Carissma                                                          2023-01-00
# Mensah, Francis Emmanuel Tofodji                                         2007-00-00
# Misra, P.                                                                2012-12-00
# Moore, H.                                                                2002-05-00
# Morse, Z.                                                                2020-12-00
# Morse, Zachary R.                                                        2021-08-00
# N'Doumi, M.                                                              2011-12-00
# Ohi, Seigo                                                               2004-02-00
# Olsen, K.                                                                2020-12-00
# Pope, Myles                                                              2023-01-00
# Qasim, Danna                                                             2022-04-00
# Reynolds, M. A.                                              2001-07-00, 2001-05-00
# Roi Smith, Sergio                                                        2017-01-00
# Sakai, R. K.                                                             2011-12-00
# Schwartzman, D. W.                                           2014-12-00, 2006-08-00
# Schwartzman, David                               2011-12-00, 2008-02-00, 2000-00-00
# Strong, Avaine                                                           2000-00-00
# Thomas, Brianna P.                               2017-01-00, 2016-01-00, 2015-01-00
# Thorpe, A. N.                                                            2002-05-00
# Vidaurri, Monica R.                                                      2022-06-00
# Walker, Ashley                       2023-01-00, 2023-01-00, 2022-12-00, 2022-12-00
# Weber, Tristan                                                           2022-12-00
# Whiteman, D. N.                                                          2020-12-00
# Wofford, A.                                                  2021-01-00, 2020-01-00
# Yarber, Aara'L.                                              2015-01-00, 2014-01-00
#
#                                                                            Keywords  \
# Input Author
# Abdullah, Ajamu                                                                 NaN
# Allen, Walter W., Jr.             Canonical proper-time, Euler-Lagrange equation...
# Anusie, Steve                                                                   NaN
# Bacha, Tulu                       Earth sciences, Clouds, Errors, Wind speed, Op...
# Blake, Ameer                                                                    NaN
# Brown, Beth A.                    black holes, space-time configurations, satell...
# Coley, J. B.                                                                    NaN
# Coley, Joel                                                                      ,
# Coley, Joel B.                    accretion, accretion disks, stars: individual:...
# David-Uraz, A.                    techniques: photometric, techniques: polarimet...
# Dumervil, S.                      0738 Ice, CRYOSPHERE, 4299 General or miscella...
# Fahr, A.                                                                        NaN
# Finch, Tehani K.                  High Energy Physics - Theory, General Relativi...
# Fletcher, Alex                                                                  NaN
# Garcia-Sanchez, Raul F.                              Analytical, Combustion, Plasma
# Halpern, J. B.                    5405 PLANETARY SCIENCES: SOLID SURFACE PLANETS...
# Howard, S. K.                     0810 Post-secondary education, EDUCATION, 0815...
# Howard, Stephanie                                                               NaN
# Howard, Stephanie K.                                                            NaN
# Hubbard, Ryan J.                                                                NaN
# Huber, Tito E.                    84.60.-h, 07.87.+v, Direct energy conversion a...
# Hughes, Andréa. C. G.             Mars, aurora, proton aurora, proton/hydrogen p...
# Hübsch, Tristan                   Supersymmetry, off-shell supermultiplets, worl...
# Jenkins, G. S.                    0343 Planetary atmospheres (5405, 5407, 5409, ...
# Jenkins, Gregory S.               Atmospheric Composition and Structure: Aerosol...
# Lewis, J. M. T.                   acetate, Mars, organic salt, oxalate, perchlor...
# Lindesay, James                   Quantum gravitation, Canonical gravitation, Ge...
# Mann, Ayanna                                                                    NaN
# Manning, Sinclaire                                                               ,
# Mbaye, Mamadou Thiao              Physics, Condensed Matter;Physics, Astronomy a...
# McGee, Carissma                                                                 NaN
# Mensah, Francis Emmanuel Tofodji  Selected overlap LIDAR, SOLEX, LIDAR, Water va...
# Misra, P.                         1976 INFORMATICS / Software tools and services...
# Moore, H.                                                       3360 Remote sensing
# Morse, Z.                         6207 Comparative planetology, PLANETARY SCIENC...
# Morse, Zachary R.                 Lunar impacts, Lunar surface, Rovers, Lunar cr...
# N'Doumi, M.                       6000 PLANETARY SCIENCES: COMETS AND SMALL BODI...
# Ohi, Seigo                        87.65.+y, 87.16.-b, 07.87.+v, Aerospace bio- a...
# Olsen, K.                         0738 Ice, CRYOSPHERE, 4299 General or miscella...
# Pope, Myles                                                                     NaN
# Qasim, Danna                      Ice destruction, Cosmic rays, Laboratory astro...
# Reynolds, M. A.                   , 2443 Midlatitude ionosphere, 2481 Topside io...
# Roi Smith, Sergio                                                               NaN
# Sakai, R. K.                      0345 ATMOSPHERIC COMPOSITION AND STRUCTURE / P...
# Schwartzman, D. W.                1605 Abrupt/rapid climate change, GLOBAL CHANG...
# Schwartzman, David                Biosphere, Encephalization, Temperature, Oxyge...
# Strong, Avaine                                                                  NaN
# Thomas, Brianna P.                                                             , ,
# Thorpe, A. N.                                                                   NaN
# Vidaurri, Monica R.               Venus, Carbon dioxide, Greenhouse gases, Habit...
# Walker, Ashley                                                               , , ,
# Weber, Tristan                    Ganymede, magnetic field, spherical harmonics,...
# Whiteman, D. N.                   0820 Curriculum and laboratory design, EDUCATI...
# Wofford, A.                                                                      ,
# Yarber, Aara'L.                                                                  ,
#
#                                                                        Affiliations  \
# Input Author
# Abdullah, Ajamu                                                   Howard University
# Allen, Walter W., Jr.                                             Howard University
# Anusie, Steve                     Howard University, Washington,\nDC, United States
# Bacha, Tulu                                                       Howard University
# Blake, Ameer                                                      Howard University
# Brown, Beth A.                    NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Coley, J. B.                      Department of Physics, Howard\nUniversity, Was...
# Coley, Joel                                   Howard University, Howard\nUniversity
# Coley, Joel B.                    Department of Physics and\nAstronomy, Howard U...
# David-Uraz, A.                    Department of Physics and\nAstronomy, and Bart...
# Dumervil, S.                      Chemical Engineering, Howard\nUniversity, Wash...
# Fahr, A.                          Howard University, Department\nof Chemistry, W...
# Finch, Tehani K.                  Department of Physics and\nAstronomy, Howard U...
# Fletcher, Alex                                                    Howard Univ., USA
# Garcia-Sanchez, Raul F.           Howard University, Department\nof Physics and ...
# Halpern, J. B.                        Chemistry, Howard Univ,\nWashington, DC, USA;
# Howard, S. K.                     Howard University, Washington,\nDC, United States
# Howard, Stephanie                     Howard University, Washington,\nUnited States
# Howard, Stephanie K.                  Howard University, Washington,\nUnited States
# Hubbard, Ryan J.                                                  Howard University
# Huber, Tito E.                    Department of Chemistry,\nHoward University, W...
# Hughes, Andréa. C. G.             NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Hübsch, Tristan                   Department of Physics and\nAstronomy, Howard U...
# Jenkins, G. S.                    Howard University, Department\nof Physics and ...
# Jenkins, Gregory S.               Department of Physics and\nAstronomy, Howard U...
# Lewis, J. M. T.                   Department of Physics and\nAstronomy, Howard U...
# Lindesay, James                   Computational Physics\nLaboratory, Howard Univ...
# Mann, Ayanna                                                      Howard University
# Manning, Sinclaire                            Howard University, Howard\nUniversity
# Mbaye, Mamadou Thiao                                              Howard University
# McGee, Carissma                                                   Howard University
# Mensah, Francis Emmanuel Tofodji                                  Howard University
# Misra, P.                         Department of Physics &amp;\nAstronomy, Howard...
# Moore, H.                         Howard University, 2355 Sixth\nSt. NW, Washing...
# Morse, Z.                         Howard University, Washington,\nDC, United States
# Morse, Zachary R.                 Department of Physics and\nAstronomy, Howard U...
# N'Doumi, M.                       Chemistry, Howard University,\nWashington, DC,...
# Ohi, Seigo                        Howard University and\nHospital, Washington, DC .
# Olsen, K.                         Physics and Astronomy, Howard\nUniversity, Was...
# Pope, Myles                                                       Howard University
# Qasim, Danna                      Astrochemistry Laboratory,\nNASA Goddard Space...
# Reynolds, M. A.                   Department of Physics and\nAstronomy, Howard U...
# Roi Smith, Sergio                                                 Howard University
# Sakai, R. K.                               Howard University, Beltsville,\nMD, USA;
# Schwartzman, D. W.                Biology, Howard University,\nWashington, DC, U...
# Schwartzman, David                Department of Biology, Howard\nUniversity, Was...
# Strong, Avaine                                    Howard University, United\nStates
# Thomas, Brianna P.                Howard University, Howard\nUniversity, Howard ...
# Thorpe, A. N.                     Department of Physics, Howard\nUniversity, Was...
# Vidaurri, Monica R.               Department of Physics and\nAstronomy, Howard U...
# Walker, Ashley                    Howard University, Howard\nUniversity, Howard ...
# Weber, Tristan                    NASA Goddard Space Flight\nCenter, Greenbelt, ...
# Whiteman, D. N.                   Howard University, Washington,\nDC, United States
# Wofford, A.                       Howard University, Washington\nD.c., DC, Howar...
# Yarber, Aara'L.                               Howard University, Howard\nUniversity
#
#                                                                            Abstract  \
# Input Author
# Abdullah, Ajamu                   NGC 3690 is a system of merging spiral galaxie...
# Allen, Walter W., Jr.             This research dissertation has three objective...
# Anusie, Steve                     Astronomers are becoming more interested in fi...
# Bacha, Tulu                       The Goddard Lidar Observatory for Wind (GLOW),...
# Blake, Ameer                      The goal of this project is to further our gro...
# Brown, Beth A.                    Dynamic space-times, especially those manifest...
# Coley, J. B.                      We report on XMM-Newton, Nuclear Spectroscopic...
# Coley, Joel                       We report on Neutron Star Interior Composition...
# Coley, Joel B.                    We report on Nuclear Spectroscopic Telescope A...
# David-Uraz, A.                    In this paper, we present results from the spe...
# Dumervil, S.                      Europa, a Galilean moon, and other icy ocean w...
# Fahr, A.                          Previously we had studied the kinetics and pro...
# Finch, Tehani K.                  The low velocity scattering of a D0-F1 supertu...
# Fletcher, Alex                    Public databases today can be constructed with...
# Garcia-Sanchez, Raul F.           Metal oxides are widely used in gas sensor app...
# Halpern, J. B.                    Relatively large hydrocarbon molecules (C4, C6...
# Howard, S. K.                     Lacking a global magnetic field and atmosphere...
# Howard, Stephanie                 In August 1989, Voyager 2 became the first and...
# Howard, Stephanie K.              During its time at Mars, MAVEN has observed mu...
# Hubbard, Ryan J.                  The efficiency with which galaxies convert gas...
# Huber, Tito E.                    Bulk Bi, a semimetal, and Bi-Sb, have the high...
# Hughes, Andréa. C. G.             Proton aurora are the most commonly observed y...
# Hübsch, Tristan                   Recent efforts to classify representations of ...
# Jenkins, G. S.                    Results from GCM simulations using boundary co...
# Jenkins, Gregory S.               We present results for multiple Saharan Air La...
# Lewis, J. M. T.                   Organic salts, such as Fe, Ca, and Mg oxalates...
# Lindesay, James                   Generic self-gravitating quantum solutions tha...
# Mann, Ayanna                      Large optical surveys have always been a very ...
# Manning, Sinclaire                We present a rotation measure survey of radio ...
# Mbaye, Mamadou Thiao              This research focus in studying the interactio...
# McGee, Carissma                   The longest recognized stellar stream in the M...
# Mensah, Francis Emmanuel Tofodji  Water vapor is one of the most important atmos...
# Misra, P.                         A library containing mass spectra for Sample A...
# Moore, H.                         We have developed a KrF Lidar system (248 nm) ...
# Morse, Z.                                                                       NaN
# Morse, Zachary R.                 Schrödinger basin, a 312 km diameter complex i...
# N'Doumi, M.                       Fluorescence (X<SUP>2</SUP>B<SUB>1</SUB> ← \At...
# Ohi, Seigo                        Astronauts experience severe/invasive disorder...
# Olsen, K.                         Enceladus' Tiger Stripe fractures and their je...
# Pope, Myles                       Mass and radius measurements for red giant sta...
# Qasim, Danna                      Gas-phase and solid-state chemistry in low-tem...
# Reynolds, M. A.                   A multispecies kinetic model of the thermal pl...
# Roi Smith, Sergio                 Pulsar timing is a powerful astrophysical tool...
# Sakai, R. K.                      During the DISCOVER-AQ experiment several plat...
# Schwartzman, D. W.                We submit that the tightly coupled coevolution...
# Schwartzman, David                We propose consideration of at least two possi...
# Strong, Avaine                    This research explores the theory of relative ...
# Thomas, Brianna P.                Finding excess infrared emission around a star...
# Thorpe, A. N.                     The saturation magnetization, saturation reman...
# Vidaurri, Monica R.               A key item of interest for planetary scientist...
# Walker, Ashley                    The atmospheric composition of the ice giants,...
# Weber, Tristan                    In this study, we use data from the Juno and G...
# Whiteman, D. N.                   We were funded to host a 2-week workshop in th...
# Wofford, A.                       Inspired by high-impact scientific results fro...
# Yarber, Aara'L.                   We present new C- and L-band VLA continuum obs...
#
#                                                                          Identifier  \
# Input Author
# Abdullah, Ajamu                                                 2014AAS...22324403A
# Allen, Walter W., Jr.                                           2009PhDT.........1A
# Anusie, Steve                                                   2019AAS...23325917A
# Bacha, Tulu                                                     2011PhDT.........7B
# Blake, Ameer                                                    2016AAS...22713710B
# Brown, Beth A.                    10.1063/1.3507200, arXiv:0904.4192, 2010AIPC.1...
# Coley, J. B.                                                    2020AAS...23545701C
# Coley, Joel                                2023AAS...24142807C, 2022HEAD...1940601C
# Coley, Joel B.                    2019ApJ...879...34C, arXiv:1905.08817, 2019arX...
# David-Uraz, A.                    2021MNRAS.tmp..907D, 2021MNRAS.504.4841D, 10.1...
# Dumervil, S.                                                    2020AGUFMP076.0002D
# Fahr, A.                                   2011DPS....43...11F, 2011epsc.conf...11F
# Finch, Tehani K.                  arXiv:hep-th/0612085, 10.48550/arXiv.hep-th/06...
# Fletcher, Alex                               2004SPIE.5371..195F, 10.1117/12.535376
# Garcia-Sanchez, Raul F.                10.15278/isms.2014.MJ07, 2014isms.confEMJ07G
# Halpern, J. B.                                                  2011AGUFM.P13A1645H
# Howard, S. K.                                                   2020AGUFMU008...06H
# Howard, Stephanie                                               2021AGUFMSM51C..06H
# Howard, Stephanie K.                                            2022AGUFMSM25A..05H
# Hubbard, Ryan J.                                                2016AAS...22733403H
# Huber, Tito E.                    2001stai.conf.1113H, 2001AIPC..552.1113H, 10.1...
# Hughes, Andréa. C. G.                     10.1029/2023JA031838, 2023JGRA..12831838H
# Hübsch, Tristan                   arXiv:1202.4342, 10.1142/S0217751X12501734, 10...
# Jenkins, G. S.                                                  2004AGUSM.U22A..05J
# Jenkins, Gregory S.               2012GeoRL..3920810J, 10.1029/2012GL053532, 200...
# Lewis, J. M. T.                           2021JGRE..12606803L, 10.1029/2020JE006803
# Lindesay, James                   2011arXiv1108.4897L, 10.1007/s10701-012-9684-2...
# Mann, Ayanna                                                    2023AAS...24120511M
# Manning, Sinclaire                         2015AAS...22514338M, 2013AAS...22144203M
# Mbaye, Mamadou Thiao                                            2014PhDT.......274M
# McGee, Carissma                                                 2023AAS...24117763M
# Mensah, Francis Emmanuel Tofodji                                2007PhDT........23M
# Misra, P.                                                       2012AGUFM.P13A1893M
# Moore, H.                                                       2002AGUSM.A22B..11M
# Morse, Z.                                                       2020AGUFMP063...02M
# Morse, Zachary R.                           10.3847/PSJ/ac0728, 2021PSJ.....2..167M
# N'Doumi, M.                                                     2011AGUFM.P33A1750N
# Ohi, Seigo                                   2004AIPC..699..938O, 10.1063/1.1649659
# Olsen, K.                                                       2020AGUFMP086...02O
# Pope, Myles                                                     2023AAS...24140126P
# Qasim, Danna                      10.3847/1538-4357/ac602b, 2022ApJ...929..176Q,...
# Reynolds, M. A.                   2001JATP...63.1267R, 10.1016/S1364-6826(00)002...
# Roi Smith, Sergio                                               2017AAS...22924203R
# Sakai, R. K.                                                    2011AGUFM.A41A0032S
# Schwartzman, D. W.                2014AGUFM.P11C3775S, 10.1016/j.gca.2006.06.104...
# Schwartzman, David                2011OLEB..tmp...41S, 2011OLEB...41..581S, 10.1...
# Strong, Avaine                                                  2000PhDT.......340S
# Thomas, Brianna P.                2017AAS...22943501T, 2016AAS...22713819T, 2015...
# Thorpe, A. N.                     2002M&PS...37..763T, 10.1111/j.1945-5100.2002....
# Vidaurri, Monica R.               2022PSJ.....3..137V, 10.3847/PSJ/ac68e2, arXiv...
# Walker, Ashley                    2023AAS...24110401W, 2023AAS...24116201W, 2022...
# Weber, Tristan                            10.1029/2022GL098633, 2022GeoRL..4998633W
# Whiteman, D. N.                                                 2020AGUFMED005..05W
# Wofford, A.                                2021AAS...23753511W, 2020AAS...23537712W
# Yarber, Aara'L.                            2015AAS...22525022Y, 2014AAS...22325219Y
#
#                                                                        Top 10 Words  \
# Input Author
# Abdullah, Ajamu                   [('star', 5), ('system', 3), ('merging', 3), (...
# Allen, Walter W., Jr.             [('equation', 6), ('formulation', 5), ('proper...
# Anusie, Steve                     [('star', 9), ('flare', 5), ('observation', 5)...
# Bacha, Tulu                       [('wind', 10), ('error', 10), ('glow', 9), ('c...
# Blake, Ameer                      [('star', 6), ('cubesat', 6), ('disk', 4), ('p...
# Brown, Beth A.                    [('black', 4), ('hole', 4), ('diagram', 3), ('...
# Coley, J. B.                      [('ray', 6), ('xmm', 4), ('newton', 4), ('tele...
# Coley, Joel                       [('nustar', 10), ('kev', 10), ('luminosity', 1...
# Coley, Joel B.                    [('superorbital', 22), ('ray', 11), ('minimum'...
# David-Uraz, A.                    [('star', 8), ('magnetic', 7), ('field', 6), (...
# Dumervil, S.                      [('europa', 9), ('ocean', 3), ('electrical', 3...
# Fahr, A.                          [('radical', 7), ('reaction', 6), ('product', ...
# Finch, Tehani K.                  [('image', 5), ('supertube', 4), ('magnificati...
# Fletcher, Alex                    [('structure', 5), ('management', 4), ('public...
# Garcia-Sanchez, Raul F.           [('gas', 10), ('temperature', 7), ('oxide', 6)...
# Halpern, J. B.                    [('radical', 8), ('reaction', 8), ('pressure',...
# Howard, S. K.                     [('wave', 9), ('solar', 6), ('wind', 6), ('mag...
# Howard, Stephanie                 [('triton', 8), ('feature', 7), ('neptune', 5)...
# Howard, Stephanie K.              [('event', 5), ('disturbance', 4), ('martian',...
# Hubbard, Ryan J.                  [('galaxy', 7), ('edig', 5), ('gas', 3), ('sta...
# Huber, Tito E.                    [('bi', 6), ('thermoelectric', 6), ('composite...
# Hughes, Andréa. C. G.             [('model', 16), ('proton', 6), ('aurora', 6), ...
# Hübsch, Tristan                   [('adinkras', 4), ('supermultiplets', 3), ('ga...
# Jenkins, G. S.                    [('high', 5), ('condition', 4), ('obliquity', ...
# Jenkins, Gregory S.               [('sal', 13), ('tropical', 10), ('ozone', 9), ...
# Lewis, J. M. T.                   [('organic', 7), ('acetate', 6), ('salt', 5), ...
# Lindesay, James                   [('quantum', 17), ('coordinate', 8), ('gravita...
# Mann, Ayanna                      [('element', 6), ('optical', 4), ('ztf', 4), (...
# Manning, Sinclaire                [('galaxy', 10), ('sample', 6), ('observed', 6...
# Mbaye, Mamadou Thiao              [('adsorption', 6), ('gas', 5), ('nanotube', 5...
# McGee, Carissma                   [('stream', 10), ('gd', 6), ('stellar', 5), ('...
# Mensah, Francis Emmanuel Tofodji  [('system', 7), ('ft', 5), ('water', 4), ('vap...
# Misra, P.                         [('library', 12), ('spectrum', 5), ('sam', 4),...
# Moore, H.                         [('interaction', 6), ('shape', 5), ('volume', ...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [('lunar', 9), ('basin', 5), ('mission', 5), (...
# ...
# Mensah, Francis Emmanuel Tofodji  [(('water', 'vapor'), 4), (('ft', 'ft'), 4), (...
# Misra, P.                         [(('normalization', 'protocol'), 3), (('gcms',...
# Moore, H.                         [(('interaction', 'volume'), 5), (('laser', 'b...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [(('schr', 'dinger'), 4), (('dinger', 'basin')...
# N'Doumi, M.                       [(('radiative', 'lifetime'), 6), (('electronic...
# Ohi, Seigo                        [(('muscle', 'loss'), 3), (('loss', 'immunodef...
# Olsen, K.                         [(('ice', 'shelf'), 6), (('stress', 'release')...
# Pope, Myles                       [(('red', 'giant'), 3), (('giant', 'star'), 3)...
# Qasim, Danna                      [(('rate', 'constant'), 5), (('constant', 'exc...
# Reynolds, M. A.                   [(('local', 'time'), 4), (('helium', 'ion'), 3...
# Roi Smith, Sergio                 [(('timing', 'model'), 3), (('model', 'provide...
# Sakai, R. K.                      [(('ozonesonde', 'tethered'), 2), (('tethered'...
# Schwartzman, D. W.                [(('geologic', 'time'), 2), (('long', 'term'),...
# Schwartzman, David                [(('path', 'encephalization'), 2), (('homeothe...
# Strong, Avaine                    [(('constellation', 'station'), 3), (('station...
# Thomas, Brianna P.                [(('host', 'star'), 3), (('debris', 'disk'), 2...
# Thorpe, A. N.                     [(('tagish', 'lake'), 3), (('multi', 'domain')...
# Vidaurri, Monica R.               [(('habitable', 'zone'), 4), (('venus', 'zone'...
# Walker, Ashley                    [(('ice', 'giant'), 12), (('aerosol', 'layer')...
# Weber, Tristan                    [(('internal', 'magnetic'), 2), (('dipole', 'a...
# Whiteman, D. N.                   [(('fully', 'virtual'), 2), (('virtual', 'expe...
# Wofford, A.                       [(('optical', 'flare'), 3), (('broader', 'impa...
# Yarber, Aara'L.                   [(('star', 'formation'), 5), (('million', 'yea...
#
#                                                                     Top 10 Trigrams  \
# Input Author
# Abdullah, Ajamu                   [(('ngc', 'system', 'merging'), 1), (('system'...
# Allen, Walter W., Jr.             [(('canonical', 'proper', 'time'), 4), (('rese...
# Anusie, Steve                     [(('muscles', 'treasury', 'survey'), 2), (('as...
# Bacha, Tulu                       [(('goddard', 'lidar', 'observatory'), 2), (('...
# Blake, Ameer                      [(('goal', 'project', 'growing'), 1), (('proje...
# Brown, Beth A.                    [(('large', 'scale', 'causal'), 2), (('black',...
# Coley, J. B.                      [(('report', 'xmm', 'newton'), 1), (('xmm', 'n...
# Coley, Joel                       [(('fe', 'fluorescent', 'emission'), 4), (('re...
# Coley, Joel B.                    [(('superorbital', 'minimum', 'maximum'), 6), ...
# David-Uraz, A.                    [(('dipolar', 'magnetic', 'field'), 2), (('res...
# Dumervil, S.                      [(('electrical', 'conductivity', 'data'), 2), ...
# Fahr, A.                          [(('previously', 'studied', 'kinetics'), 1), (...
# Finch, Tehani K.                  [(('low', 'velocity', 'scattering'), 1), (('ve...
# Fletcher, Alex                    [(('internet', 'search', 'engines'), 2), (('pu...
# Garcia-Sanchez, Raul F.           [(('metal', 'oxide', 'gas'), 2), (('wo', 'sili...
# Halpern, J. B.                    [(('large', 'hydrocarbon', 'molecules'), 1), (...
# Howard, S. K.                     [(('ultra', 'low', 'frequency'), 2), (('low', ...
# Howard, Stephanie                 [(('august', 'voyager', 'spacecraft'), 1), (('...
# Howard, Stephanie K.              [(('martian', 'magnetosphere', 'due'), 2), (('...
# Hubbard, Ryan J.                  [(('accretion', 'feedback', 'processes'), 2), ...
# Huber, Tito E.                    [(('bulk', 'bi', 'semimetal'), 1), (('bi', 'se...
# Hughes, Andréa. C. G.             [(('martian', 'proton', 'aurora'), 2), (('mode...
# Hübsch, Tristan                   [(('recent', 'efforts', 'classify'), 1), (('ef...
# Jenkins, G. S.                    [(('results', 'gcm', 'simulations'), 1), (('gc...
# Jenkins, Gregory S.               [(('ozone', 'mixing', 'ratios'), 3), (('middle...
# Lewis, J. M. T.                   [(('organic', 'salts', 'fe'), 1), (('salts', '...
# Lindesay, James                   [(('geometries', 'horizons', 'offer'), 2), (('...
# Mann, Ayanna                      [(('large', 'optical', 'surveys'), 2), (('wide...
# Manning, Sinclaire                [(('star', 'formation', 'induced'), 2), (('rot...
# Mbaye, Mamadou Thiao              [(('consequence', 'heat', 'capacity'), 2), (('...
# McGee, Carissma                   [(('gd', 'stellar', 'stream'), 2), (('longest'...
# Mensah, Francis Emmanuel Tofodji  [(('ft', 'ft', 'ft'), 3), (('water', 'vapor', ...
# Misra, P.                         [(('library', 'mass', 'spectra'), 1), (('mass'...
# Moore, H.                         [(('temporal', 'shape', 'returned'), 2), (('si...
# Morse, Z.                                                                        []
# Morse, Zachary R.                 [(('schr', 'dinger', 'basin'), 3), (('dinger',...
# N'Doumi, M.                       [(('electronically', 'excited', 'state'), 3), ...
# Ohi, Seigo                        [(('astronauts', 'experience', 'severe'), 1), ...
# Olsen, K.                         [(('enceladus', 'tiger', 'stripe'), 2), (('tig...
# Pope, Myles                       [(('red', 'giant', 'stars'), 3), (('mass', 'ra...
# Qasim, Danna                      [(('rate', 'constants', 'exchange'), 2), (('ga...
# Reynolds, M. A.                   [(('helium', 'ion', 'density'), 2), (('local',...
# Roi Smith, Sergio                 [(('timing', 'models', 'provide'), 2), (('mode...
# Sakai, R. K.                      [(('ozonesonde', 'tethered', 'balloon'), 2), (...
# Schwartzman, D. W.                [(('submit', 'tightly', 'coupled'), 1), (('tig...
# Schwartzman, David                [(('propose', 'consideration', 'evolutionary')...
# Strong, Avaine                    [(('constellation', 'station', 'keeping'), 3),...
# Thomas, Brianna P.                [(('percent', 'frequency', 'sources'), 2), (('...
# Thorpe, A. N.                     [(('tagish', 'lake', 'meteorite'), 2), (('mult...
# Vidaurri, Monica R.               [(('outer', 'edge', 'venus'), 2), (('edge', 'v...
# Walker, Ashley                    [(('atmospheric', 'composition', 'ice'), 3), (...
# Weber, Tristan                    [(('study', 'data', 'juno'), 1), (('data', 'ju...
# Whiteman, D. N.                   [(('fully', 'virtual', 'experience'), 2), (('f...
# Wofford, A.                       [(('radio', 'bursts', 'optical'), 2), (('burst...
# Yarber, Aara'L.                   [(('band', 'vla', 'continuum'), 1), (('vla', '...
#
#                                                           Data Type  \
# Input Author
# Abdullah, Ajamu                                               Clean
# Allen, Walter W., Jr.                                         Dirty
# Anusie, Steve                                                 Clean
# Bacha, Tulu                                                   Dirty
# Blake, Ameer                                                  Clean
# Brown, Beth A.                                         Dirty, Dirty
# Coley, J. B.                                                  Clean
# Coley, Joel                                            Clean, Dirty
# Coley, Joel B.                                  Clean, Clean, Clean
# David-Uraz, A.                                         Clean, Clean
# Dumervil, S.                                                  Dirty
# Fahr, A.                                                      Dirty
# Finch, Tehani K.                                       Dirty, Clean
# Fletcher, Alex                                                Clean
# Garcia-Sanchez, Raul F.                                       Dirty
# Halpern, J. B.                                                Dirty
# Howard, S. K.                                                 Dirty
# Howard, Stephanie                                             Dirty
# Howard, Stephanie K.                                          Dirty
# Hubbard, Ryan J.                                              Clean
# Huber, Tito E.                                                Dirty
# Hughes, Andréa. C. G.                                         Dirty
# Hübsch, Tristan                                        Dirty, Dirty
# Jenkins, G. S.                                                Dirty
# Jenkins, Gregory S.               Dirty, Dirty, Dirty, Dirty, Dirty
# Lewis, J. M. T.                                               Dirty
# Lindesay, James                   Dirty, Dirty, Dirty, Dirty, Dirty
# Mann, Ayanna                                                  Clean
# Manning, Sinclaire                                     Clean, Clean
# Mbaye, Mamadou Thiao                                          Dirty
# McGee, Carissma                                               Clean
# Mensah, Francis Emmanuel Tofodji                              Dirty
# Misra, P.                                                     Dirty
# Moore, H.                                                     Dirty
# Morse, Z.                                                     Dirty
# Morse, Zachary R.                                             Dirty
# N'Doumi, M.                                                   Dirty
# Ohi, Seigo                                                    Dirty
# Olsen, K.                                                     Dirty
# Pope, Myles                                                   Clean
# Qasim, Danna                                                  Clean
# Reynolds, M. A.                                        Dirty, Dirty
# Roi Smith, Sergio                                             Clean
# Sakai, R. K.                                                  Dirty
# Schwartzman, D. W.                                     Dirty, Dirty
# Schwartzman, David                              Dirty, Dirty, Dirty
# Strong, Avaine                                                Dirty
# Thomas, Brianna P.                              Clean, Clean, Clean
# Thorpe, A. N.                                                 Dirty
# Vidaurri, Monica R.                                           Dirty
# Walker, Ashley                           Clean, Clean, Dirty, Dirty
# Weber, Tristan                                                Dirty
# Whiteman, D. N.                                               Dirty
# Wofford, A.                                            Clean, Clean
# Yarber, Aara'L.                                        Clean, Clean
#
#                                                                            arxiv-id
# Input Author
# Abdullah, Ajamu                                                                None
# Allen, Walter W., Jr.                                                          None
# Anusie, Steve                                                                  None
# Bacha, Tulu                                                                    None
# Blake, Ameer                                                                   None
# Brown, Beth A.                                                 0904.4192, 0710.2032
# Coley, J. B.                                                                   None
# Coley, Joel                                                                    None
# Coley, Joel B.                                                           1905.08817
# David-Uraz, A.                                               2004.09698, 2010.07482
# Dumervil, S.                                                                   None
# Fahr, A.                                                                       None
# Finch, Tehani K.                                   hep-th/0612085, astro-ph/0205489
# Fletcher, Alex                                                                 None
# Garcia-Sanchez, Raul F.                                                        None
# Halpern, J. B.                                                                 None
# Howard, S. K.                                                                  None
# Howard, Stephanie                                                              None
# Howard, Stephanie K.                                                           None
# Hubbard, Ryan J.                                                               None
# Huber, Tito E.                                                                 None
# Hughes, Andréa. C. G.                                                          None
# Hübsch, Tristan                                                           1202.4342
# Jenkins, G. S.                                                                 None
# Jenkins, Gregory S.                                                            None
# Lewis, J. M. T.                                                                None
# Lindesay, James                   1108.4897, 1005.4449, 0904.4195, 0810.4515, gr...
# Mann, Ayanna                                                                   None
# Manning, Sinclaire                                                             None
# Mbaye, Mamadou Thiao                                                           None
# McGee, Carissma                                                                None
# Mensah, Francis Emmanuel Tofodji                                               None
# Misra, P.                                                                      None
# Moore, H.                                                                      None
# Morse, Z.                                                                      None
# Morse, Zachary R.                                                              None
# N'Doumi, M.                                                                    None
# Ohi, Seigo                                                                     None
# Olsen, K.                                                                      None
# Pope, Myles                                                                    None
# Qasim, Danna                                                             2204.13212
# Reynolds, M. A.                                                                None
# Roi Smith, Sergio                                                              None
# Sakai, R. K.                                                                   None
# Schwartzman, D. W.                                                             None
# Schwartzman, David                                                             None
# Strong, Avaine                                                                 None
# Thomas, Brianna P.                                                             None
# Thorpe, A. N.                                                                  None
# Vidaurri, Monica R.                                                      2204.10919
# Walker, Ashley                                                                 None
# Weber, Tristan                                                                 None
# Whiteman, D. N.                                                                None
# Wofford, A.                                                                    None
# Yarber, Aara'L.                                                                None

# %% [markdown]
# **Download PDF version of ArXiv papers**
#
# Run time for 20 papers is approximately 10s.

# %%
download_directory = '/content/'
pdf_filenames = []

def download_pdf(identifier):
    pdf_url = f'https://arxiv.org/pdf/{identifier}.pdf'
    save_path = os.path.join(download_directory, f'{identifier.replace("/", "_")}.pdf')
    response = requests.get(pdf_url)

    if response.status_code == 200:
        with open(save_path, 'wb') as pdf_file:
            pdf_file.write(response.content)
        return save_path
    return None

all_identifiers = [identifier for row in datf['arxiv-id'].str.split(', ') for identifier in row if identifier != 'None']

with concurrent.futures.ThreadPoolExecutor(max_workers = 20) as executor:
    results = list(executor.map(download_pdf, all_identifiers))

pdf_filenames.extend(result for result in results if result is not None)

#print(pdf_filenames)

# %% [markdown]
# **Process Text Files**
#
# Large Language Models need information passed through in the form of an ASCII file to perfom its functions properly. Information from the original pdf versions, like tables, references, acknowledgements, etc. can result in hallucinations in the model. Removing this information is vital after converting the infromation from pdf to txt.

# %%
def remove_text_in_brackets(text):
  pattern = r'\([^)]*\)|\[[^\]]*\]'
  return re.sub(pattern, '', text)

def remove_lines_starting_with_number_or_symbol(text):
  pattern = r'^[\d\W].*$'
  return re.sub(pattern, '', text, flags=re.MULTILINE)

def remove_lines_with_one_word(text):
  lines = text.split('\n')
  pattern = r'^\s*\w+\s*$'
  filtered_lines = [line for line in lines if not re.match(pattern, line)]
  return '\n'.join(filtered_lines)

def remove_empty_lines(text):
  lines = text.split('\n')
  non_empty_lines = [line for line in lines if line.strip() != '']
  return '\n'.join(non_empty_lines)

def find_and_remove_references(text, keywords):
  earliest_position = -1
  for keyword in keywords:
    position = text.find(keyword)
    if position != -1:
      earliest_position = position if earliest_position == -1 else min(position, earliest_position)
  if earliest_position != -1:
    text = text[:earliest_position]
  return text

def process_text(text):
  keywords = ["REFERENCES", "ACKNOWLEDGEMENTS", "References", "Acknowledgements"]

  text = find_and_remove_references(text, keywords)
  text = find_and_remove_references(text, keywords)
  text = remove_text_in_brackets(text)
  text = remove_lines_starting_with_number_or_symbol(text)
  text = remove_lines_with_one_word(text)
  text = remove_empty_lines(text)

  return text

def extract_and_process_text(pdf_path, output_path):
  pdf_doc = fitz.open(pdf_path)
  text = ''
  for page in  pdf_doc:
    text += page.get_text()

  lines = text.split('\n')
  filtered_lines = [line for line in lines if len(line.strip()) > 1]
  filtered_text = '\n'.join(filtered_lines)
  cleaned_text = process_text(filtered_text)

  with open(output_path, 'w', encoding = 'utf-8') as output_file:
    output_file.write(cleaned_text)
  return output_path

def process_pdf(pdf_filename):
  text_filename = pdf_filename.replace('.pdf','.txt')
  cleaned_text = extract_and_process_text(pdf_filename, text_filename)
  return text_filename

text_filenames = []

num_workers = 100

with concurrent.futures.ThreadPoolExecutor(max_workers = num_workers) as executor:
  results = list(executor.map(process_pdf, pdf_filenames))

text_filenames.extend(result for result in results if result is not None)

#print(text_filenames)

# %% [markdown]
# **Summarization Model**

# %%
hf_tag = "pszemraj/led-large-book-summary"

_device = torch.cuda.current_device() if torch.cuda.is_available() else torch.device("cpu")

model = AutoModelForSeq2SeqLM.from_pretrained(hf_tag).to(_device)

tokenizer = AutoTokenizer.from_pretrained(hf_tag)

token_batch_length = 3072
batch_stride = 50
max_len_ratio = 8

settings = {
    'min_length': 5,
    'max_length': int(token_batch_length // max_len_ratio),
    'no_repeat_ngram_size': 7,
    'encoder_no_repeat_ngram_size' : 7,
    'repetition_penalty': 3.7,
    'num_beams': 12,
    'length_penalty': 0.5,
    'early_stopping': True,
    'do_sample': False}

logging.info(f"using textgen params:\n\n:{settings}")

def summarize(ids, mask, **kwargs):
    ids = ids[None, :]
    mask = mask[None, :]

    input_ids = ids.to(_device)
    attention_mask = mask.to(_device)
    global_attention_mask = torch.zeros_like(attention_mask)
    global_attention_mask[:, 0] = 1

    summary_pred_ids = model.generate(
        ids,
        attention_mask=mask,
        global_attention_mask=global_attention_mask,
        return_dict_in_generate=True,
        **kwargs)
    summary = tokenizer.batch_decode(
        summary_pred_ids.sequences,
        skip_special_tokens=True,
        remove_invalid_values=True,)

    return summary

def summarize_via_tokenbatches(input_text, **kwargs):
    encoded_input = tokenizer(
        input_text,
        padding='max_length',
        truncation=True,
        max_length=token_batch_length,
        stride=batch_stride,
        return_overflowing_tokens=True,
        add_special_tokens=False,
        return_tensors='pt',)

    in_id_arr, att_arr = encoded_input.input_ids.to(_device), encoded_input.attention_mask.to(_device)
    gen_summaries = []

    with tqdm(total=len(in_id_arr)) as pbar:
        for _id, _mask in zip(in_id_arr, att_arr):
            result = summarize(ids=_id, mask=_mask, **kwargs)
            _sum = {"input_tokens": _id, "summary": result}
            gen_summaries.append(_sum)
            pbar.update()

    return gen_summaries

directory = '/content/'
text_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.txt')]


for file_path in text_files:
  with open(file_path, 'r', errors='ignore') as f:
    raw_text = f.read()

  long_text = clean(raw_text)
  logging.info(f"removed {len(long_text) - len(raw_text)} chars via cleaning")

  encoded_input = tokenizer(
    long_text,
    padding='max_length',
    truncation=True,
    max_length=token_batch_length,
    stride=batch_stride,
    return_overflowing_tokens=True,
    add_special_tokens =False,
    return_tensors='pt',)

  _summaries = summarize_via_tokenbatches(long_text, **settings)

  sum_text = [s["summary"][0] for s in _summaries]
  full_summary = "\n\t".join(sum_text)

  path = Path(file_path)
  _outpath = f"SUM_{path.name}"

  with open(_outpath,"w",) as fo:
    fo.writelines(full_summary)
    fo.write("\n" * 3)
    fo.write("\n\n---\n")

  if torch.cuda.is_available():
    torch.cuda.empty_cache()

num_workers = 4

with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
    executor.map(summarize, text_files)

# !cat $_outpath
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# In this paper, the authors summarize the results from the spectroscopic follow-up of the first phase of the mobster mission and report the discovery of three new magnetic b stars. Of the four targets from the mobster, one--hd 25709--has a detectable surface magnetic field and is classified as an "oba", while the others have lower detection limits. They also report the discovery of a previously unknown binary star, hd 25709, and provide criteria for the selection of larger sample of stars to be followed up later on using high-resolution spectrophotometry. The authors estimate that there are currently only 11 known magnetic b stars and less than 100 known magnetic o-type stars, and with the cost of telescope equipment, it is not possible to survey large swatches of the sky with sufficient resolution to determine their true nature. Instead, they recommend that indirect methods such as photometry be used to identify candidates for further study. In this paper, they describe the approach they used to select candidates for further study and present the results from their initial observations. The authors perform a systematic analysis of the acquired data using a technique called "lomb-scargle frequency analysis," which allows them to predict the strength of the magnetic fields observed. They then perform a Bayesian analysis using unconstrained rotational dynamics to calculate the surface field strengths. Finally, they fit a keplerian orbits to the radial velocity and projected rotational velocities calculated from diffraction measurements. The authors note that the primary and secondary stars differ in temperature and luminosity from each other but do not appear to have very different temperatures and masses.
# 	This paper describes the initial results of our new method for detecting magnetic signals from distant stars. In this first study, we obtain an upper limit of "bd, max = 63 gmnras 000, /t/t", corresponding to the effective temperature, luminosity, and other characteristics of a b-type star. We also explore three other stars: hd 30963, hd 38170, hd 30963B, hd 30963C, and hd 38170A new magnetic b star. The authors note that although it is not a b-type star, it does appear to be chemically peculiar as it is overabundant with strontium and barium. They detect a weak magnetic field around its surface, but do not observe any discernible magnetic resistance. Of the four stars in our survey, hd 38170 appears to be the most promising candidate for detecting a magnetic field due to its small size, compactness, dimness, and brightness. Our model predicts that this star should be easy to locate using stellar parameters such as luminosity, surface gravity, polar radius, mass, age, etc. Further investigation will be required to determine its exact composition and age. The authors suggest that this discovery could aid in determining the proper types of follow-up investigations to determine the origin and evolution of magnetism in massive stars like hd 38170. Finally, they discuss the specific to look for sources of photometric variability in order to select candidates for future surveys. They exclude binary stars because they are more likely to exhibit non-magnetic sources of light than those with stable magnetic fields.
# 	This paper discusses the current state of the science concerning hgmn stars and their properties. The authors note that due to the small size of the survey, there are few candidates eligible for the "tar-geted" survey, which means that they cannot be directly surveyed. They do, however, plan to use future detections will help improve their candidate selection criteria in order to iteratively improve their "candidate selection criteria. This will lead to a "high-yield survey" and "a high-yield survey," which will lead to a better statistics on the population of massive and intermediate-mass magnetic stars. The authors conclude by noting that despite the limited number of candidate magnetic stars involved, this survey will still be very useful as it will allow them to iteratively improve their candidate selection criteria and will enable them to iteratively improve their tooling.
#
#
#
#
# ---

# %% [markdown]
# **Combine Summaries for Given Author**
#
# To understand the expertise of the author, we need to include all possible publications, so that we see an overarching view of their work.

# %%
datf['Summaries'] = ""

for index,row in datf.iterrows():
  identifiers = row['arxiv-id'].split(',')

  concat_summ = ""

  for identifier in identifiers:
    if identifier.strip() == 'None':
      concat_summ = 'None'
      break

    sanitized_identifier = identifier.strip().replace('/', '_')

    filename = f'SUM_{sanitized_identifier}.txt'

    if os.path.exists(filename):
      with open(filename, 'r', encoding = 'utf-8') as file:
        concat_summ += file.read()
    else:
      concat_summ = 'File not found'

  datf.at[index, 'Summaries'] = concat_summ

# %%
datf.reset_index(inplace = True)

# %% [markdown]
# **N_grams**

# %%
def sum_n_grams(df, directorypath): #directory path should lead to TextAnalysis.py
    top10Dict = {'Summaries Top 10 Words':[],
                 'Summaries Top 10 Bigrams':[],
                 'Summaries Top 10 Trigrams':[]}

    for i in df.values:
        summaries = i[15]

        top10words = TA.topwords(summaries, directorypath)
        top10bigrams = TA.topbigrams(summaries, directorypath)
        top10trigrams = TA.toptrigrams(summaries, directorypath)

        top10Dict['Summaries Top 10 Words'].append(top10words)
        top10Dict['Summaries Top 10 Bigrams'].append(top10bigrams)
        top10Dict['Summaries Top 10 Trigrams'].append(top10trigrams)

    sum_top10Df = df
    sum_top10Df['Summaries Top 10 Words'] = top10Dict['Summaries Top 10 Words']
    sum_top10Df['Summaries Top 10 Bigrams'] = top10Dict['Summaries Top 10 Bigrams']
    sum_top10Df['Summaries Top 10 Trigrams'] = top10Dict['Summaries Top 10 Trigrams']

    sum_top10Df = sum_top10Df[['Input Author', 'Input Institution', 'First Author', 'Bibcode', 'Title', 'Publication Date',
             'Keywords', 'Affiliations', 'Abstract', 'Top 10 Words', 'Top 10 Bigrams', 'Top 10 Trigrams', 'Data Type',
            'arxiv-id', 'Summaries', 'Summaries Top 10 Words', 'Summaries Top 10 Bigrams', 'Summaries Top 10 Trigrams']]

    return sum_top10Df

# %%
path_stop= '/content/'
stop_file='stopwords.txt'
stop_dir=path_stop+stop_file

final_df = sum_n_grams(datf, stop_dir)
#final_df

# %% [markdown]
# **Save New File**
#
# Change the name from results to preferred naming convention.

# %%
final_df.to_csv('Results.csv', index = False)
